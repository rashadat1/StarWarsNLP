# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
import torch, nltk

# %% [markdown]
# ## Load Model

# %%
model_ckpt = 'dslim/bert-large-NER'
device = 'mps' if torch.backends.mps.is_available() else 'cpu'

def load_model(task, model_ckpt, device):
    
    tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
    model = AutoModelForTokenClassification.from_pretrained(model_ckpt)
    
    task_pipeline = pipeline(task=task,model=model,tokenizer=tokenizer,device=device)
    return task_pipeline

ner_pipeline = load_model('ner',model_ckpt,device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import pandas as pd
subtitle_path = '../data/subtitles.txt'

def datasetprocessing(path):
    dialogue = []
    with open(subtitle_path,'r') as file:
        lines = file.readlines()
        lines = lines[1:]
        for line in lines:
            quote = line.split(',')[2]
            dialogue.append(quote.replace('"',''))
        script = " ".join(dialogue)
    return script

script = datasetprocessing(subtitle_path)

# %%
script
# Out:
# "Did you hear that?  They've shut down the main reactor.  We'll be destroyed for sure.  This is madness!\n We're doomed!\n There'll be no escape for the Princess this time.\n What's that?\n I should have known better than to trust the logic of a half-sized thermocapsulary dehousing assister...\n Hurry up!  Come with me!  What are you waiting for?!  Get in gear!\n Artoo! Artoo-Detoo At last!  Where have you been?\n They're heading in this direction. What are we going to do?  We'll be sent to the spice mines of Kessel or smashed into who knows what!\n Wait a minute The Death Star plans are not in the main computer.\n Where are those transmissions you intercepted?\n We intercepted no transmissions. Aaah...  This is a consular ship. Were on a diplomatic mission.\n If this is a consular ship... where is the Ambassador?\n Commander There she is! Set for stun!\n She'll be all right. Inform Lord Vader we have a prisoner.\n Hey Don't call me a mindless philosopher Secret mission?  What plans?  What are you talking about?  I'm not getting in there!\n I'm going to regret this.\n There goes another one.\n Hold your fire.  There are no life forms.  It must have been short-circuited.\n That's funny Are you sure this things safe?\n I've told you kids to slow down!\n Did I hear a young noise blast through here?\n It was just Wormie on another rampage.\n Shape it up you guys!...  Biggs?\n I didn't know you were back!  When did you get in?\n Just now.  I wanted to surprise you The Academy didn't change you much... but you're back so soon?  Hey Of course I got it.  Signed aboard The Rand Ecliptic last week.  First mate Biggs Darklighter at your service...... I just came back to say goodbye to all you unfortunate landlocked simpletons.\n I almost forgot.  There's a battle going on!  Right here in our system.  Come and look!\n Not again!  Forget it.\n There they are!\n That's no battle But there was a lot of firing earlier...\n Hey Don't worry about it I keep telling you Lord Vader Don't play games with me I don't know what you're talking about.  I'm a member of the Imperial Senate on a diplomatic mission to Alderaan...\n You're a part of the Rebel Alliance... and a traitor.  Take her away!\n Holding her is dangerous.  If word of this gets out I have traced the Rebel spies to her.  Now she is my only link to find their secret base!\n you anything.\n Leave that to me.  Send a distress signal and then inform the senate that all aboard were killed!\n Lord Vader She must have hidden the plans in the escape pod.  Send a detachment down to retrieve them.  See to it personally Yes How did I get into this mess?  I really don't know how.  We seem to be made to suffer.  It's our lot in life.\n I've got to rest before I fall apart.  My joints are almost frozen. \n What a desolate place this is.\n Where are you going?\n Well What makes you think there are settlements over there?\n Don't get technical with me.\n What mission?  What are you talking about?  I've had just about enough of you!  Go that way!  You'll be malfunctioning within a day And don't let me catch you following me begging for help No more adventures.  I'm not going that way.\n That malfunctioning little twerp.  This is all his fault!  He tricked me into going this way Wait Over here!  Help!  Please ... so I cut off my power You ought to take it a little easy Luke.  You may be the hottest bushpilot this side of Mos Eisley Look who's talking.  Now that you've been around those giant starships you're beginning to sound like my uncle. You've gotten soft in the city...\n I've missed you kid.\n Well Luke What are you talking about?\n I made some friends at the Academy. ... when our frigate goes to one of the central systems Join the Rebellion?!  Are you kidding!  How?\n Quiet down will ya!  You got a mouth bigger than a meteor crater!\n I'm sorry.  I'm quiet. Listen how quiet I am.  You can barely hear me...\n My friend has a friend on Bestine who might help us make contact.\n around forever trying  ...

# %%
script_sentences = nltk.sent_tokenize(script)

# %%
docs = ner_pipeline(script_sentences)

# %%
docs
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.38675198,
#    'index': 1,
#    'word': 'Art',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.33464313,
#    'index': 2,
#    'word': '##oo',
#    'start': 3,
#    'end': 5}],
#  [{'entity': 'B-PER',
#    'score': 0.9732834,
#    'index': 1,
#    'word': 'Art',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.5314915,
#    'index': 2,
#    'word': '##oo',
#    'start': 3,
#    'end': 5},
#   {'entity': 'B-PER',
#    'score': 0.9635247,
#    'index': 4,
#    'word': 'Det',
#    'start': 6,
#    'end': 9},
#   {'entity': 'I-PER',
#    'score': 0.50105655,
#    'index': 5,
#    'word': '##oo',
#    'start': 9,
#    'end': 11}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9962553,
#    'index': 12,
#    'word': 'Ke',
#    'start': 36,
#    'end': 38},
#   {'entity': 'I-LOC',
#    'score': 0.9713103,
#    'index': 13,
#    'word': '##ssel',
#    'start': 38,
#    'end': 42}],
#  [{'entity': 'B-ORG',
#    'score': 0.89310354,
#    'index': 4,
#    'word': 'The',
#    'start': 14,
#    'end': 17},
#   {'entity': 'I-ORG',
#    'score': 0.65661734,
#    'index': 5,
#    'word': 'Death',
#    'start': 18,
#    'end': 23},
#   {'entity': 'I-MISC',
#    'score': 0.50257057,
#    'index': 6,
#    'word': 'Star',
#    'start': 24,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'I-PER',
#    'score': 0.4761405,
#    'index': 4,
#    'word': 'V',
#    'start': 12,
#    'end': 13},
#   {'entity': 'I-PER',
#    'score': 0.44096982,
#    'index': 5,
#    'word': '##ader',
#    'start': 13,
#    'end': 17}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9922724,
#    'index': 4,
#    'word': 'W',
#    'start': 12,
#    'end': 13},
#   {'entity': 'I-PER',
#    'score': 0.7200914,
#    'index': 5,
#    'word': '##orm',
#    'start': 13,
#    'end': 16},
#   {'entity': 'I-PER',
#    'score': 0.62502795,
#    'index': 6,
#    'word': '##ie',
#    'start': 16,
#    'end': 18}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9270324,
#    'index': 1,
#    'word': 'Big',
#    'start': 0,
#    'end': 3}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6851436,
#    'index': 6,
#    'word': 'The',
#    'start': 25,
#    'end': 28},
#   {'entity': 'I-MISC',
#    'score': 0.59888303,
#    'index': 7,
#    'word': 'Academy',
#    'start': 29,
#    'end': 36}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.98430353,
#    'index': 4,
#    'word': 'The',
#    'start': 14,
#    'end': 17},
#   {'entity': 'I-ORG',
#    'score': 0.9897022,
#    'index': 5,
#    'word': 'Rand',
#    'start': 18,
#    'end': 22},
#   {'entity': 'I-ORG',
#    'score': 0.98254675,
#    'index': 6,
#    'word': 'E',
#    'start': 23,
#    'end': 24},
#   {'entity': 'I-ORG',
#    'score': 0.83262855,
#    'index': 7,
#    'word': '##c',
#    'start': 24,
#    'end': 25},
#   {'entity': 'I-ORG',
#    'score': 0.9018893,
#    'index': 8,
#    'word': '##liptic',
#    'start': 25,
#    'end': 31}],
#  [{'entity': 'B-PER',
#    'score': 0.99740285,
#    'index': 3,
#    'word': 'Big',
#    'start': 11,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.94579357,
#    'index': 4,
#    'word': '##gs',
#    'start': 14,
#    'end': 16},
#   {'entity': 'I-PER',
#    'score': 0.99670804,
#    'index': 5,
#    'word': 'Dark',
#    'start': 17,
#    'end': 21},
#   {'entity': 'I-PER',
#    'score': 0.87788516,
#    'index': 6,
#    'word': '##light',
#    'start': 21,
#    'end': 26},
#   {'entity': 'I-PER',
#    'score': 0.68902844,
#    'index': 7,
#    'word': '##er',
#    'start': 26,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.52707344,
#    'index': 28,
#    'word': 'Lord',
#    'start': 103,
#    'end': 107},
#   {'entity': 'I-PER',
#    'score': 0.8989799,
#    'index': 29,
#    'word': 'V',
#    'start': 108,
#    'end': 109},
#   {'entity': 'I-PER',
#    'score': 0.65086514,
#    'index': 30,
#    'word': '##ader',
#    'start': 109,
#    'end': 113}],
#  [{'entity': 'B-ORG',
#    'score': 0.9949092,
#    'index': 8,
#    'word': 'Imperial',
#    'start': 20,
#    'end': 28},
#   {'entity': 'I-ORG',
#    'score': 0.99690956,
#    'index': 9,
#    'word': 'Senate',
#    'start': 29,
#    'end': 35},
#   {'entity': 'B-LOC',
#    'score': 0.9945623,
#    'index': 15,
#    'word': 'Al',
#    'start': 63,
#    'end': 65},
#   {'entity': 'I-LOC',
#    'score': 0.9937722,
#    'index': 16,
#    'word': '##der',
#    'start': 65,
#    'end': 68},
#   {'entity': 'I-LOC',
#    'score': 0.9947983,
#    'index': 17,
#    'word': '##aan',
#    'start': 68,
#    'end': 71},
#   {'entity': 'B-ORG',
#    'score': 0.99310315,
#    'index': 28,
#    'word': 'Rebel',
#    'start': 97,
#    'end': 102},
#   {'entity': 'I-ORG',
#    'score': 0.9937981,
#    'index': 29,
#    'word': 'Alliance',
#    'start': 103,
#    'end': 111}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.96983296,
#    'index': 11,
#    'word': 'Rebel',
#    'start': 43,
#    'end': 48}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9011323,
#    'index': 1,
#    'word': 'Lord',
#    'start': 0,
#    'end': 4},
#   {'entity': 'I-PER',
#    'score': 0.9922197,
#    'index': 2,
#    'word': 'V',
#    'start': 5,
#    'end': 6},
#   {'entity': 'I-PER',
#    'score': 0.8861951,
#    'index': 3,
#    'word': '##ader',
#    'start': 6,
#    'end': 10}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6742065,
#    'index': 1,
#    'word': 'Help',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.9856629,
#    'index': 19,
#    'word': 'Luke',
#    'start': 68,
#    'end': 72}],
#  [{'entity': 'B-PER',
#    'score': 0.9921027,
#    'index': 13,
#    'word': 'Mo',
#    'start': 46,
#    'end': 48},
#   {'entity': 'I-PER',
#    'score': 0.6453494,
#    'index': 14,
#    'word': '##s',
#    'start': 48,
#    'end': 49},
#   {'entity': 'I-PER',
#    'score': 0.9931035,
#    'index': 15,
#    'word': 'E',
#    'start': 50,
#    'end': 51},
#   {'entity': 'I-PER',
#    'score': 0.82626987,
#    'index': 16,
#    'word': '##is',
#    'start': 51,
#    'end': 53},
#   {'entity': 'I-PER',
#    'score': 0.68258756,
#    'index': 17,
#    'word': '##ley',
#    'start': 53,
#    'end': 56}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.91994745,
#    'index': 2,
#    'word': 'Luke',
#    'start': 5,
#    'end': 9}],
#  [{'entity': 'B-ORG',
#    'score': 0.9735901,
#    'index': 7,
#    'word': 'Academy',
#    'start': 27,
#    'end': 34}],
#  [{'entity': 'I-MISC',
#    'score': 0.43015078,
#    'index': 17,
#    'word': 'Rebellion',
#    'start': 65,
#    'end': 74}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6376587,
#    'index': 15,
#    'word': 'Best',
#    'start': 53,
#    'end': 57},
#   {'entity': 'I-ORG',
#    'score': 0.4833818,
#    'index': 16,
#    'word': '##ine',
#    'start': 57,
#    'end': 60}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9934941,
#    'index': 8,
#    'word': 'Academy',
#    'start': 32,
#    'end': 39}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.84388137,
#    'index': 10,
#    'word': 'Sand',
#    'start': 41,
#    'end': 45},
#   {'entity': 'I-ORG',
#    'score': 0.8518013,
#    'index': 11,
#    'word': 'People',
#    'start': 46,
#    'end': 52},
#   {'entity': 'B-LOC',
#    'score': 0.9932462,
#    'index': 26,
#    'word': 'An',
#    'start': 108,
#    'end': 110},
#   {'entity': 'I-LOC',
#    'score': 0.97285163,
#    'index': 27,
#    'word': '##chor',
#    'start': 110,
#    'end': 114},
#   {'entity': 'I-LOC',
#    'score': 0.9965444,
#    'index': 28,
#    'word': '##head',
#    'start': 114,
#    'end': 118}],
#  [{'entity': 'B-MISC',
#    'score': 0.9621742,
#    'index': 10,
#    'word': 'Sand',
#    'start': 44,
#    'end': 48},
#   {'entity': 'I-MISC',
#    'score': 0.96850735,
#    'index': 11,
#    'word': 'People',
#    'start': 49,
#    'end': 55}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9114377,
#    'index': 2,
#    'word': 'Empire',
#    'start': 4,
#    'end': 10}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9416152,
#    'index': 4,
#    'word': 'Art',
#    'start': 13,
#    'end': 16},
#   {'entity': 'I-PER',
#    'score': 0.27112088,
#    'index': 5,
#    'word': '##oo',
#    'start': 16,
#    'end': 18},
#   {'entity': 'B-PER',
#    'score': 0.6758897,
#    'index': 7,
#    'word': 'Det',
#    'start': 19,
#    'end': 22}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.7809467,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.97905225,
#    'index': 10,
#    'word': 'Bo',
#    'start': 31,
#    'end': 33},
#   {'entity': 'I-MISC',
#    'score': 0.89386916,
#    'index': 11,
#    'word': '##cc',
#    'start': 33,
#    'end': 35},
#   {'entity': 'I-MISC',
#    'score': 0.99015665,
#    'index': 12,
#    'word': '##e',
#    'start': 35,
#    'end': 36}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9921015,
#    'index': 4,
#    'word': 'Luke',
#    'start': 12,
#    'end': 16},
#   {'entity': 'B-LOC',
#    'score': 0.95402104,
#    'index': 10,
#    'word': 'To',
#    'start': 38,
#    'end': 40},
#   {'entity': 'I-LOC',
#    'score': 0.7871449,
#    'index': 11,
#    'word': '##shi',
#    'start': 40,
#    'end': 43},
#   {'entity': 'I-LOC',
#    'score': 0.963873,
#    'index': 12,
#    'word': 'Station',
#    'start': 44,
#    'end': 51}],
#  [{'entity': 'B-PER',
#    'score': 0.7229297,
#    'index': 5,
#    'word': 'Owen',
#    'start': 20,
#    'end': 24}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.8608715,
#    'index': 5,
#    'word': 'Owen',
#    'start': 20,
#    'end': 24}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.94047606,
#    'index': 15,
#    'word': 'Luke',
#    'start': 47,
#    'end': 51}],
#  [{'entity': 'B-PER',
#    'score': 0.9510888,
#    'index': 4,
#    'word': 'See',
#    'start': 9,
#    'end': 12},
#   {'entity': 'I-PER',
#    'score': 0.8374008,
#    'index': 6,
#    'word': 'Three',
#    'start': 13,
#    'end': 18},
#   {'entity': 'I-PER',
#    'score': 0.73507494,
#    'index': 7,
#    'word': '##pio',
#    'start': 18,
#    'end': 21}],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.6421677,
#    'index': 15,
#    'word': 'Empire',
#    'start': 66,
#    'end': 72}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9288205,
#    'index': 12,
#    'word': 'O',
#    'start': 45,
#    'end': 46},
#   {'entity': 'I-PER',
#    'score': 0.6555626,
#    'index': 13,
#    'word': '##bi',
#    'start': 46,
#    'end': 48},
#   {'entity': 'I-PER',
#    'score': 0.48767212,
#    'index': 14,
#    'word': '-',
#    'start': 48,
#    'end': 49},
#   {'entity': 'I-PER',
#    'score': 0.8041555,
#    'index': 15,
#    'word': 'Wan',
#    'start': 49,
#    'end': 52},
#   {'entity': 'I-PER',
#    'score': 0.9739653,
#    'index': 16,
#    'word': 'Ken',
#    'start': 53,
#    'end': 56},
#   {'entity': 'I-PER',
#    'score': 0.75448525,
#    'index': 17,
#    'word': '##ob',
#    'start': 56,
#    'end': 58},
#   {'entity': 'I-PER',
#    'score': 0.32239538,
#    'index': 18,
#    'word': '##i',
#    'start': 58,
#    'end': 59},
#   {'entity': 'B-PER',
#    'score': 0.8137039,
#    'index': 19,
#    'word': 'O',
#    'start': 60,
#    'end': 61},
#   {'entity': 'I-PER',
#    'score': 0.5533119,
#    'index': 20,
#    'word': '##bi',
#    'start': 61,
#    'end': 63},
#   {'entity': 'I-PER',
#    'score': 0.50458497,
#    'index': 21,
#    'word': '-',
#    'start': 63,
#    'end': 64},
#   {'entity': 'I-PER',
#    'score': 0.7765509,
#    'index': 22,
#    'word': 'Wan',
#    'start': 64,
#    'end': 67},
#   {'entity': 'I-PER',
#    'score': 0.97731745,
#    'index': 23,
#    'word': 'Ken',
#    'start': 68,
#    'end': 71},
#   {'entity': 'I-PER',
#    'score': 0.7677718,
#    'index': 24,
#    'word': '##ob',
#    'start': 71,
#    'end': 73},
#   {'entity': 'I-PER',
#    'score': 0.51741064,
#    'index': 25,
#    'word': '##i',
#    'start': 73,
#    'end': 74}],
#  [{'entity': 'B-PER',
#    'score': 0.9966959,
#    'index': 7,
#    'word': 'Ben',
#    'start': 25,
#    'end': 28},
#   {'entity': 'I-PER',
#    'score': 0.9975942,
#    'index': 8,
#    'word': 'Ken',
#    'start': 29,
#    'end': 32},
#   {'entity': 'I-PER',
#    'score': 0.92498374,
#    'index': 9,
#    'word': '##ob',
#    'start': 32,
#    'end': 34},
#   {'entity': 'I-PER',
#    'score': 0.9021789,
#    'index': 10,
#    'word': '##i',
#    'start': 34,
#    'end': 35}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9277292,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.49646726,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.95190537,
#    'index': 8,
#    'word': 'Ben',
#    'start': 35,
#    'end': 38}],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.8977443,
#    'index': 12,
#    'word': 'An',
#    'start': 46,
#    'end': 48},
#   {'entity': 'I-LOC',
#    'score': 0.96242315,
#    'index': 13,
#    'word': '##chor',
#    'start': 48,
#    'end': 52},
#   {'entity': 'I-LOC',
#    'score': 0.9537103,
#    'index': 14,
#    'word': '##head',
#    'start': 52,
#    'end': 56}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.98384315,
#    'index': 5,
#    'word': 'O',
#    'start': 17,
#    'end': 18},
#   {'entity': 'I-PER',
#    'score': 0.7942782,
#    'index': 6,
#    'word': '##bi',
#    'start': 18,
#    'end': 20},
#   {'entity': 'I-PER',
#    'score': 0.56943583,
#    'index': 7,
#    'word': '-',
#    'start': 20,
#    'end': 21},
#   {'entity': 'I-PER',
#    'score': 0.84894115,
#    'index': 8,
#    'word': 'Wan',
#    'start': 21,
#    'end': 24}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.3124341,
#    'index': 2,
#    'word': 'Harvest',
#    'start': 5,
#    'end': 12}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.978828,
#    'index': 8,
#    'word': 'Academy',
#    'start': 27,
#    'end': 34}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99267817,
#    'index': 1,
#    'word': 'Owen',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99418056,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.8630254,
#    'index': 12,
#    'word': 'Sand',
#    'start': 42,
#    'end': 46},
#   {'entity': 'I-MISC',
#    'score': 0.8381694,
#    'index': 13,
#    'word': 'People',
#    'start': 47,
#    'end': 53}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.98952544,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.6815836,
#    'index': 2,
#    'word': 'Luke',
#    'start': 3,
#    'end': 7}],
#  [{'entity': 'B-PER',
#    'score': 0.9277292,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.9277292,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.97669595,
#    'index': 4,
#    'word': 'Luke',
#    'start': 14,
#    'end': 18}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.98852473,
#    'index': 2,
#    'word': 'Ben',
#    'start': 4,
#    'end': 7},
#   {'entity': 'I-PER',
#    'score': 0.9986374,
#    'index': 3,
#    'word': 'Ken',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-PER',
#    'score': 0.9608432,
#    'index': 4,
#    'word': '##ob',
#    'start': 11,
#    'end': 13},
#   {'entity': 'I-PER',
#    'score': 0.87669903,
#    'index': 5,
#    'word': '##i',
#    'start': 13,
#    'end': 14},
#   {'entity': 'B-PER',
#    'score': 0.53358155,
#    'index': 12,
#    'word': 'Sir',
#    'start': 53,
#    'end': 56},
#   {'entity': 'I-PER',
#    'score': 0.68648726,
#    'index': 13,
#    'word': 'Sure',
#    'start': 57,
#    'end': 61}],
#  [],
#  [],
#  [{'entity': 'I-PER',
#    'score': 0.95697516,
#    'index': 5,
#    'word': 'Luke',
#    'start': 21,
#    'end': 25}],
#  [{'entity': 'B-PER',
#    'score': 0.73744684,
#    'index': 9,
#    'word': 'O',
#    'start': 27,
#    'end': 28},
#   {'entity': 'I-PER',
#    'score': 0.85518533,
#    'index': 10,
#    'word': '##bi',
#    'start': 28,
#    'end': 30},
#   {'entity': 'I-PER',
#    'score': 0.5591042,
#    'index': 11,
#    'word': '-',
#    'start': 30,
#    'end': 31},
#   {'entity': 'I-PER',
#    'score': 0.8174832,
#    'index': 12,
#    'word': 'Wan',
#    'start': 31,
#    'end': 34},
#   {'entity': 'I-PER',
#    'score': 0.9686763,
#    'index': 13,
#    'word': 'Ken',
#    'start': 35,
#    'end': 38},
#   {'entity': 'I-PER',
#    'score': 0.85258824,
#    'index': 14,
#    'word': '##ob',
#    'start': 38,
#    'end': 40},
#   {'entity': 'I-MISC',
#    'score': 0.5760737,
#    'index': 15,
#    'word': '##i',
#    'start': 40,
#    'end': 41}],
#  [{'entity': 'B-MISC',
#    'score': 0.5672516,
#    'index': 7,
#    'word': 'Sand',
#    'start': 13,
#    'end': 17},
#   {'entity': 'I-ORG',
#    'score': 0.47515425,
#    'index': 8,
#    'word': 'People',
#    'start': 18,
#    'end': 24}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9737081,
#    'index': 6,
#    'word': 'Ban',
#    'start': 22,
#    'end': 25},
#   {'entity': 'I-MISC',
#    'score': 0.87160605,
#    'index': 7,
#    'word': '##tha',
#    'start': 25,
#    'end': 28},
#   {'entity': 'I-MISC',
#    'score': 0.6225336,
#    'index': 8,
#    'word': '##s',
#    'start': 28,
#    'end': 29}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.98329216,
#    'index': 3,
#    'word': 'Ben',
#    'start': 10,
#    'end': 13}],
#  [{'entity': 'B-PER',
#    'score': 0.594134,
#    'index': 1,
#    'word': 'Ben',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.8776134,
#    'index': 2,
#    'word': 'Ken',
#    'start': 4,
#    'end': 7},
#   {'entity': 'I-PER',
#    'score': 0.7178634,
#    'index': 3,
#    'word': '##ob',
#    'start': 7,
#    'end': 9}],
#  [{'entity': 'B-LOC',
#    'score': 0.9536328,
#    'index': 3,
#    'word': 'Jun',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-LOC',
#    'score': 0.90108234,
#    'index': 4,
#    'word': '##dl',
#    'start': 11,
#    'end': 13},
#   {'entity': 'I-LOC',
#    'score': 0.97432953,
#    'index': 5,
#    'word': '##and',
#    'start': 13,
#    'end': 16},
#   {'entity': 'I-LOC',
#    'score': 0.9792422,
#    'index': 6,
#    'word': 'Waste',
#    'start': 17,
#    'end': 22},
#   {'entity': 'I-LOC',
#    'score': 0.8925023,
#    'index': 7,
#    'word': '##s',
#    'start': 22,
#    'end': 23}],
#  [{'entity': 'B-PER',
#    'score': 0.680723,
#    'index': 3,
#    'word': 'Oh',
#    'start': 8,
#    'end': 10},
#   {'entity': 'B-PER',
#    'score': 0.6074388,
#    'index': 4,
#    'word': 'O',
#    'start': 11,
#    'end': 12},
#   {'entity': 'I-PER',
#    'score': 0.61795497,
#    'index': 5,
#    'word': '##bi',
#    'start': 12,
#    'end': 14},
#   {'entity': 'I-MISC',
#    'score': 0.3360647,
#    'index': 6,
#    'word': '-',
#    'start': 14,
#    'end': 15},
#   {'entity': 'I-PER',
#    'score': 0.5000812,
#    'index': 7,
#    'word': 'Wan',
#    'start': 15,
#    'end': 18},
#   {'entity': 'I-PER',
#    'score': 0.9332155,
#    'index': 8,
#    'word': 'Ken',
#    'start': 19,
#    'end': 22},
#   {'entity': 'I-PER',
#    'score': 0.73585325,
#    'index': 9,
#    'word': '##ob',
#    'start': 22,
#    'end': 24},
#   {'entity': 'I-PER',
#    'score': 0.3876648,
#    'index': 10,
#    'word': '##i',
#    'start': 24,
#    'end': 25},
#   {'entity': 'B-PER',
#    'score': 0.8850041,
#    'index': 14,
#    'word': 'O',
#    'start': 29,
#    'end': 30},
#   {'entity': 'I-PER',
#    'score': 0.596068,
#    'index': 15,
#    'word': '##bi',
#    'start': 30,
#    'end': 32},
#   {'entity': 'I-MISC',
#    'score': 0.49402675,
#    'index': 16,
#    'word': '-',
#    'start': 32,
#    'end': 33},
#   {'entity': 'I-PER',
#    'score': 0.4495385,
#    'index': 17,
#    'word': 'Wan',
#    'start': 33,
#    'end': 36}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.5871214,
#    'index': 2,
#    'word': 'Sand',
#    'start': 4,
#    'end': 8},
#   {'entity': 'I-MISC',
#    'score': 0.6799751,
#    'index': 3,
#    'word': 'People',
#    'start': 9,
#    'end': 15}],
#  [{'entity': 'B-ORG',
#    'score': 0.4056755,
#    'index': 4,
#    'word': 'Three',
#    'start': 4,
#    'end': 9}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.66545326,
#    'index': 12,
#    'word': 'Sand',
#    'start': 40,
#    'end': 44},
#   {'entity': 'I-ORG',
#    'score': 0.76053125,
#    'index': 13,
#    'word': 'People',
#    'start': 45,
#    'end': 51}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9980076,
#    'index': 5,
#    'word': 'C',
#    'start': 18,
#    'end': 19},
#   {'entity': 'I-MISC',
#    'score': 0.87692153,
#    'index': 6,
#    'word': '##lone',
#    'start': 19,
#    'end': 23},
#   {'entity': 'I-MISC',
#    'score': 0.9964588,
#    'index': 7,
#    'word': 'Wars',
#    'start': 24,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9783362,
#    'index': 7,
#    'word': 'Jed',
#    'start': 24,
#    'end': 27},
#   {'entity': 'I-MISC',
#    'score': 0.9417944,
#    'index': 8,
#    'word': '##i',
#    'start': 27,
#    'end': 28},
#   {'entity': 'I-MISC',
#    'score': 0.8582274,
#    'index': 9,
#    'word': 'Knight',
#    'start': 29,
#    'end': 35}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9093126,
#    'index': 7,
#    'word': 'Jed',
#    'start': 36,
#    'end': 39},
#   {'entity': 'I-MISC',
#    'score': 0.7698478,
#    'index': 8,
#    'word': '##i',
#    'start': 39,
#    'end': 40},
#   {'entity': 'I-ORG',
#    'score': 0.5326479,
#    'index': 9,
#    'word': 'Knights',
#    'start': 41,
#    'end': 48},
#   {'entity': 'B-LOC',
#    'score': 0.9782056,
#    'index': 20,
#    'word': 'Old',
#    'start': 96,
#    'end': 99},
#   {'entity': 'I-LOC',
#    'score': 0.991264,
#    'index': 21,
#    'word': 'Republic',
#    'start': 100,
#    'end': 108}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.98201907,
#    'index': 3,
#    'word': 'Jed',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-MISC',
#    'score': 0.956731,
#    'index': 4,
#    'word': '##i',
#    'start': 11,
#    'end': 12},
#   {'entity': 'B-PER',
#    'score': 0.99711275,
#    'index': 6,
#    'word': 'Dar',
#    'start': 19,
#    'end': 22},
#   {'entity': 'I-PER',
#    'score': 0.9059921,
#    'index': 7,
#    'word': '##th',
#    'start': 22,
#    'end': 24},
#   {'entity': 'I-PER',
#    'score': 0.99715745,
#    'index': 8,
#    'word': 'V',
#    'start': 25,
#    'end': 26},
#   {'entity': 'I-PER',
#    'score': 0.9839189,
#    'index': 9,
#    'word': '##ader',
#    'start': 26,
#    'end': 30},
#   {'entity': 'B-ORG',
#    'score': 0.76525205,
#    'index': 10,
#    'word': 'The',
#    'start': 31,
#    'end': 34},
#   {'entity': 'I-ORG',
#    'score': 0.56151205,
#    'index': 11,
#    'word': 'Force',
#    'start': 35,
#    'end': 40}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.97838223,
#    'index': 2,
#    'word': 'Ken',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-PER',
#    'score': 0.9679051,
#    'index': 3,
#    'word': '##ob',
#    'start': 11,
#    'end': 13},
#   {'entity': 'I-PER',
#    'score': 0.9513087,
#    'index': 4,
#    'word': '##i',
#    'start': 13,
#    'end': 14},
#   {'entity': 'B-ORG',
#    'score': 0.9797084,
#    'index': 12,
#    'word': 'Force',
#    'start': 46,
#    'end': 51},
#   {'entity': 'B-LOC',
#    'score': 0.9975914,
#    'index': 22,
#    'word': 'Al',
#    'start': 81,
#    'end': 83},
#   {'entity': 'I-LOC',
#    'score': 0.9958711,
#    'index': 23,
#    'word': '##der',
#    'start': 83,
#    'end': 86},
#   {'entity': 'I-LOC',
#    'score': 0.9973091,
#    'index': 24,
#    'word': '##aan',
#    'start': 86,
#    'end': 89}],
#  [{'entity': 'B-LOC',
#    'score': 0.71335447,
#    'index': 1,
#    'word': 'Al',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-LOC',
#    'score': 0.5882824,
#    'index': 3,
#    'word': '##aan',
#    'start': 5,
#    'end': 8}],
#  [{'entity': 'B-LOC',
#    'score': 0.994921,
#    'index': 7,
#    'word': 'Al',
#    'start': 17,
#    'end': 19},
#   {'entity': 'I-LOC',
#    'score': 0.99388087,
#    'index': 9,
#    'word': '##aan',
#    'start': 22,
#    'end': 25}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.5922184,
#    'index': 9,
#    'word': 'Empire',
#    'start': 25,
#    'end': 31}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9981469,
#    'index': 2,
#    'word': 'Rebel',
#    'start': 4,
#    'end': 9},
#   {'entity': 'I-ORG',
#    'score': 0.9971929,
#    'index': 3,
#    'word': 'Alliance',
#    'start': 10,
#    'end': 18}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.38344437,
#    'index': 8,
#    'word': 'Rebellion',
#    'start': 32,
#    'end': 41},
#   {'entity': 'B-ORG',
#    'score': 0.82877034,
#    'index': 16,
#    'word': 'Imperial',
#    'start': 79,
#    'end': 87},
#   {'entity': 'I-ORG',
#    'score': 0.910577,
#    'index': 17,
#    'word': 'Senate',
#    'start': 88,
#    'end': 94}],
#  [{'entity': 'B-ORG',
#    'score': 0.9878884,
#    'index': 2,
#    'word': 'Imperial',
#    'start': 4,
#    'end': 12},
#   {'entity': 'I-ORG',
#    'score': 0.9936686,
#    'index': 3,
#    'word': 'Senate',
#    'start': 13,
#    'end': 19}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.87426656,
#    'index': 6,
#    'word': 'Old',
#    'start': 25,
#    'end': 28},
#   {'entity': 'I-MISC',
#    'score': 0.72742915,
#    'index': 7,
#    'word': 'Republic',
#    'start': 29,
#    'end': 37}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.38520965,
#    'index': 5,
#    'word': 'Rebellion',
#    'start': 16,
#    'end': 25}],
#  [{'entity': 'B-MISC',
#    'score': 0.87144303,
#    'index': 3,
#    'word': 'Rebels',
#    'start': 7,
#    'end': 13}],
#  [{'entity': 'B-MISC',
#    'score': 0.9407768,
#    'index': 6,
#    'word': 'Rebels',
#    'start': 23,
#    'end': 29}],
#  [{'entity': 'B-ORG',
#    'score': 0.95897895,
#    'index': 17,
#    'word': 'Force',
#    'start': 74,
#    'end': 79}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.8888367,
#    'index': 1,
#    'word': 'V',
#    'start': 0,
#    'end': 1},
#   {'entity': 'I-PER',
#    'score': 0.3716721,
#    'index': 2,
#    'word': '##ader',
#    'start': 1,
#    'end': 5}],
#  [],
#  [{'entity': 'I-PER',
#    'score': 0.7764024,
#    'index': 2,
#    'word': 'V',
#    'start': 5,
#    'end': 6},
#   {'entity': 'I-PER',
#    'score': 0.7636909,
#    'index': 3,
#    'word': '##ader',
#    'start': 6,
#    'end': 10},
#   {'entity': 'B-MISC',
#    'score': 0.9636994,
#    'index': 12,
#    'word': 'Rebel',
#    'start': 52,
#    'end': 57}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9675995,
#    'index': 4,
#    'word': 'Sand',
#    'start': 14,
#    'end': 18},
#   {'entity': 'I-ORG',
#    'score': 0.9715917,
#    'index': 5,
#    'word': 'People',
#    'start': 19,
#    'end': 25}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.6850922,
#    'index': 1,
#    'word': 'Sand',
#    'start': 0,
#    'end': 4},
#   {'entity': 'I-MISC',
#    'score': 0.7281737,
#    'index': 2,
#    'word': 'People',
#    'start': 5,
#    'end': 11}],
#  [{'entity': 'B-MISC',
#    'score': 0.63803566,
#    'index': 5,
#    'word': 'J',
#    'start': 19,
#    'end': 20},
#   {'entity': 'I-MISC',
#    'score': 0.5429098,
#    'index': 6,
#    'word': '##awa',
#    'start': 20,
#    'end': 23},
#   {'entity': 'I-MISC',
#    'score': 0.6754604,
#    'index': 7,
#    'word': '##s',
#    'start': 23,
#    'end': 24},
#   {'entity': 'B-PER',
#    'score': 0.965278,
#    'index': 11,
#    'word': 'Art',
#    'start': 38,
#    'end': 41},
#   {'entity': 'I-ORG',
#    'score': 0.54766876,
#    'index': 12,
#    'word': '##oo',
#    'start': 41,
#    'end': 43},
#   {'entity': 'B-PER',
#    'score': 0.9640835,
#    'index': 14,
#    'word': 'Three',
#    'start': 48,
#    'end': 53},
#   {'entity': 'I-PER',
#    'score': 0.68889344,
#    'index': 15,
#    'word': '##pio',
#    'start': 53,
#    'end': 56}],
#  [{'entity': 'B-MISC',
#    'score': 0.9887812,
#    'index': 7,
#    'word': 'Imperial',
#    'start': 33,
#    'end': 41},
#   {'entity': 'B-PER',
#    'score': 0.8495638,
#    'index': 12,
#    'word': 'J',
#    'start': 67,
#    'end': 68}],
#  [{'entity': 'I-PER',
#    'score': 0.45920232,
#    'index': 9,
#    'word': 'Owen',
#    'start': 42,
#    'end': 46}],
#  [{'entity': 'I-PER',
#    'score': 0.4728136,
#    'index': 2,
#    'word': 'Be',
#    'start': 5,
#    'end': 7}],
#  [{'entity': 'B-PER',
#    'score': 0.5404899,
#    'index': 2,
#    'word': 'Owen',
#    'start': 6,
#    'end': 10}],
#  [{'entity': 'B-LOC',
#    'score': 0.99759656,
#    'index': 17,
#    'word': 'Al',
#    'start': 67,
#    'end': 69},
#   {'entity': 'I-LOC',
#    'score': 0.989684,
#    'index': 18,
#    'word': '##der',
#    'start': 69,
#    'end': 72},
#   {'entity': 'I-LOC',
#    'score': 0.9970681,
#    'index': 19,
#    'word': '##aan',
#    'start': 72,
#    'end': 75}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.8951052,
#    'index': 9,
#    'word': 'Force',
#    'start': 32,
#    'end': 37},
#   {'entity': 'B-MISC',
#    'score': 0.97104114,
#    'index': 13,
#    'word': 'Jed',
#    'start': 51,
#    'end': 54},
#   {'entity': 'I-MISC',
#    'score': 0.95460624,
#    'index': 14,
#    'word': '##i',
#    'start': 54,
#    'end': 55}],
#  [{'entity': 'B-ORG',
#    'score': 0.9862586,
#    'index': 1,
#    'word': 'Mo',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-ORG',
#    'score': 0.97683525,
#    'index': 2,
#    'word': '##s',
#    'start': 2,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.9638258,
#    'index': 3,
#    'word': 'E',
#    'start': 4,
#    'end': 5},
#   {'entity': 'I-ORG',
#    'score': 0.84792006,
#    'index': 4,
#    'word': '##is',
#    'start': 5,
#    'end': 7},
#   {'entity': 'I-ORG',
#    'score': 0.9775614,
#    'index': 5,
#    'word': '##ley',
#    'start': 7,
#    'end': 10},
#   {'entity': 'I-ORG',
#    'score': 0.98264515,
#    'index': 6,
#    'word': 'Space',
#    'start': 11,
#    'end': 16},
#   {'entity': 'I-ORG',
#    'score': 0.90877986,
#    'index': 7,
#    'word': '##port',
#    'start': 16,
#    'end': 20}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9861449,
#    'index': 8,
#    'word': 'J',
#    'start': 20,
#    'end': 21},
#   {'entity': 'I-MISC',
#    'score': 0.9143228,
#    'index': 9,
#    'word': '##awa',
#    'start': 21,
#    'end': 24}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9606964,
#    'index': 3,
#    'word': 'The',
#    'start': 6,
#    'end': 9},
#   {'entity': 'I-ORG',
#    'score': 0.89947855,
#    'index': 4,
#    'word': 'Force',
#    'start': 10,
#    'end': 15}],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9965054,
#    'index': 20,
#    'word': 'Al',
#    'start': 72,
#    'end': 74},
#   {'entity': 'I-LOC',
#    'score': 0.99218315,
#    'index': 21,
#    'word': '##der',
#    'start': 74,
#    'end': 77},
#   {'entity': 'I-LOC',
#    'score': 0.9936819,
#    'index': 22,
#    'word': '##aan',
#    'start': 77,
#    'end': 80}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.98442507,
#    'index': 3,
#    'word': 'Ch',
#    'start': 8,
#    'end': 10},
#   {'entity': 'I-PER',
#    'score': 0.8487434,
#    'index': 4,
#    'word': '##ew',
#    'start': 10,
#    'end': 12},
#   {'entity': 'I-PER',
#    'score': 0.8441181,
#    'index': 5,
#    'word': '##ba',
#    'start': 12,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.28954628,
#    'index': 6,
#    'word': '##cca',
#    'start': 14,
#    'end': 17}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9803256,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.9927182,
#    'index': 2,
#    'word': 'Solo',
#    'start': 4,
#    'end': 8}],
#  [{'entity': 'B-MISC',
#    'score': 0.88704264,
#    'index': 7,
#    'word': 'Millennium',
#    'start': 19,
#    'end': 29},
#   {'entity': 'I-MISC',
#    'score': 0.93784016,
#    'index': 8,
#    'word': 'Falcon',
#    'start': 30,
#    'end': 36}],
#  [{'entity': 'B-PER',
#    'score': 0.9974075,
#    'index': 1,
#    'word': 'Ch',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-PER',
#    'score': 0.5210843,
#    'index': 2,
#    'word': '##ew',
#    'start': 2,
#    'end': 4},
#   {'entity': 'B-PER',
#    'score': 0.52477115,
#    'index': 3,
#    'word': '##ie',
#    'start': 4,
#    'end': 6},
#   {'entity': 'B-LOC',
#    'score': 0.9599964,
#    'index': 15,
#    'word': 'Al',
#    'start': 55,
#    'end': 57},
#   {'entity': 'I-LOC',
#    'score': 0.9762245,
#    'index': 16,
#    'word': '##der',
#    'start': 57,
#    'end': 60},
#   {'entity': 'I-LOC',
#    'score': 0.9496691,
#    'index': 17,
#    'word': '##aan',
#    'start': 60,
#    'end': 63}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9956923,
#    'index': 8,
#    'word': 'Millennium',
#    'start': 26,
#    'end': 36},
#   {'entity': 'I-MISC',
#    'score': 0.9968418,
#    'index': 9,
#    'word': 'Falcon',
#    'start': 37,
#    'end': 43}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.99615943,
#    'index': 9,
#    'word': 'Ke',
#    'start': 28,
#    'end': 30},
#   {'entity': 'I-MISC',
#    'score': 0.9901552,
#    'index': 10,
#    'word': '##ssel',
#    'start': 30,
#    'end': 34}],
#  [{'entity': 'B-MISC',
#    'score': 0.9946569,
#    'index': 6,
#    'word': 'Imperial',
#    'start': 12,
#    'end': 20}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.99511576,
#    'index': 13,
#    'word': 'Imperial',
#    'start': 38,
#    'end': 46}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.85582757,
#    'index': 1,
#    'word': 'J',
#    'start': 0,
#    'end': 1},
#   {'entity': 'I-PER',
#    'score': 0.41290134,
#    'index': 2,
#    'word': '##ab',
#    'start': 1,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.227807,
#    'index': 3,
#    'word': '##ba',
#    'start': 3,
#    'end': 5}],
#  [{'entity': 'B-PER',
#    'score': 0.9935715,
#    'index': 2,
#    'word': 'J',
#    'start': 5,
#    'end': 6},
#   {'entity': 'I-PER',
#    'score': 0.5100382,
#    'index': 3,
#    'word': '##ab',
#    'start': 6,
#    'end': 8},
#   {'entity': 'I-PER',
#    'score': 0.36794657,
#    'index': 4,
#    'word': '##ba',
#    'start': 8,
#    'end': 10},
#   {'entity': 'B-PER',
#    'score': 0.992388,
#    'index': 8,
#    'word': 'J',
#    'start': 15,
#    'end': 16},
#   {'entity': 'I-PER',
#    'score': 0.5510408,
#    'index': 9,
#    'word': '##ab',
#    'start': 16,
#    'end': 18},
#   {'entity': 'I-PER',
#    'score': 0.34362966,
#    'index': 10,
#    'word': '##ba',
#    'start': 18,
#    'end': 20}],
#  [{'entity': 'B-MISC',
#    'score': 0.99339193,
#    'index': 20,
#    'word': 'Imperial',
#    'start': 78,
#    'end': 86}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9894104,
#    'index': 6,
#    'word': 'J',
#    'start': 21,
#    'end': 22},
#   {'entity': 'I-PER',
#    'score': 0.37682587,
#    'index': 7,
#    'word': '##ab',
#    'start': 22,
#    'end': 24}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.922915,
#    'index': 20,
#    'word': 'Le',
#    'start': 94,
#    'end': 96},
#   {'entity': 'I-LOC',
#    'score': 0.37120575,
#    'index': 21,
#    'word': '##ia',
#    'start': 96,
#    'end': 98},
#   {'entity': 'B-LOC',
#    'score': 0.9974751,
#    'index': 27,
#    'word': 'Al',
#    'start': 116,
#    'end': 118},
#   {'entity': 'I-LOC',
#    'score': 0.9963813,
#    'index': 29,
#    'word': '##aan',
#    'start': 121,
#    'end': 124}],
#  [],
#  [{'entity': 'I-PER',
#    'score': 0.9298371,
#    'index': 14,
#    'word': 'Luke',
#    'start': 66,
#    'end': 70}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.99119204,
#    'index': 3,
#    'word': 'X',
#    'start': 10,
#    'end': 11},
#   {'entity': 'I-MISC',
#    'score': 0.9854327,
#    'index': 4,
#    'word': '##P',
#    'start': 11,
#    'end': 12},
#   {'entity': 'I-MISC',
#    'score': 0.95316315,
#    'index': 5,
#    'word': '-',
#    'start': 12,
#    'end': 13},
#   {'entity': 'I-MISC',
#    'score': 0.9516647,
#    'index': 6,
#    'word': '38',
#    'start': 13,
#    'end': 15}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99220484,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.94042414,
#    'index': 2,
#    'word': 'You',
#    'start': 4,
#    'end': 7},
#   {'entity': 'B-PER',
#    'score': 0.99332833,
#    'index': 4,
#    'word': 'G',
#    'start': 13,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.8946125,
#    'index': 5,
#    'word': '##reed',
#    'start': 14,
#    'end': 18},
#   {'entity': 'I-PER',
#    'score': 0.9276043,
#    'index': 6,
#    'word': '##o',
#    'start': 18,
#    'end': 19}],
#  [{'entity': 'B-PER',
#    'score': 0.9499328,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.63879585,
#    'index': 11,
#    'word': 'Han',
#    'start': 37,
#    'end': 40}],
#  [{'entity': 'B-PER',
#    'score': 0.9498954,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.93981886,
#    'index': 2,
#    'word': 'J',
#    'start': 4,
#    'end': 5},
#   {'entity': 'I-PER',
#    'score': 0.9281505,
#    'index': 3,
#    'word': '##ab',
#    'start': 5,
#    'end': 7},
#   {'entity': 'I-PER',
#    'score': 0.754735,
#    'index': 4,
#    'word': '##ba',
#    'start': 7,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.61493796,
#    'index': 1,
#    'word': 'B',
#    'start': 0,
#    'end': 1}],
#  [{'entity': 'B-PER',
#    'score': 0.984769,
#    'index': 1,
#    'word': 'Ch',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-PER',
#    'score': 0.9197385,
#    'index': 2,
#    'word': '##ew',
#    'start': 2,
#    'end': 4},
#   {'entity': 'I-PER',
#    'score': 0.84087783,
#    'index': 3,
#    'word': '##ie',
#    'start': 4,
#    'end': 6},
#   {'entity': 'I-PER',
#    'score': 0.98492926,
#    'index': 4,
#    'word': 'Oh',
#    'start': 7,
#    'end': 9},
#   {'entity': 'B-MISC',
#    'score': 0.9753145,
#    'index': 9,
#    'word': 'Imperial',
#    'start': 27,
#    'end': 35}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9014933,
#    'index': 10,
#    'word': 'Al',
#    'start': 39,
#    'end': 41},
#   {'entity': 'I-LOC',
#    'score': 0.9760785,
#    'index': 11,
#    'word': '##der',
#    'start': 41,
#    'end': 44},
#   {'entity': 'I-LOC',
#    'score': 0.9251181,
#    'index': 12,
#    'word': '##aan',
#    'start': 44,
#    'end': 47}],
#  [{'entity': 'B-PER',
#    'score': 0.9970841,
#    'index': 2,
#    'word': 'Ta',
#    'start': 9,
#    'end': 11},
#   {'entity': 'I-PER',
#    'score': 0.96833557,
#    'index': 3,
#    'word': '##rkin',
#    'start': 11,
#    'end': 15},
#   {'entity': 'I-PER',
#    'score': 0.9968412,
#    'index': 4,
#    'word': 'Cha',
#    'start': 16,
#    'end': 19},
#   {'entity': 'I-PER',
#    'score': 0.9828987,
#    'index': 5,
#    'word': '##rming',
#    'start': 19,
#    'end': 24}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.91292495,
#    'index': 2,
#    'word': 'Le',
#    'start': 9,
#    'end': 11},
#   {'entity': 'I-PER',
#    'score': 0.3011389,
#    'index': 3,
#    'word': '##ia',
#    'start': 11,
#    'end': 13}],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9946957,
#    'index': 1,
#    'word': 'Al',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-LOC',
#    'score': 0.9945333,
#    'index': 2,
#    'word': '##der',
#    'start': 2,
#    'end': 5},
#   {'entity': 'I-LOC',
#    'score': 0.99799466,
#    'index': 3,
#    'word': '##aan',
#    'start': 5,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.94588107,
#    'index': 4,
#    'word': 'Rebel',
#    'start': 13,
#    'end': 18}],
#  [{'entity': 'B-ORG',
#    'score': 0.8802668,
#    'index': 1,
#    'word': 'Dan',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.8967072,
#    'index': 2,
#    'word': '##to',
#    'start': 3,
#    'end': 5},
#   {'entity': 'I-ORG',
#    'score': 0.70711595,
#    'index': 3,
#    'word': '##oi',
#    'start': 5,
#    'end': 7},
#   {'entity': 'I-ORG',
#    'score': 0.9220833,
#    'index': 4,
#    'word': '##ne',
#    'start': 7,
#    'end': 9}],
#  [{'entity': 'B-LOC',
#    'score': 0.9730708,
#    'index': 5,
#    'word': 'Dan',
#    'start': 11,
#    'end': 14},
#   {'entity': 'I-LOC',
#    'score': 0.9681883,
#    'index': 6,
#    'word': '##to',
#    'start': 14,
#    'end': 16},
#   {'entity': 'I-LOC',
#    'score': 0.7343955,
#    'index': 7,
#    'word': '##oi',
#    'start': 16,
#    'end': 18},
#   {'entity': 'I-LOC',
#    'score': 0.9437016,
#    'index': 8,
#    'word': '##ne',
#    'start': 18,
#    'end': 20}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9177954,
#    'index': 3,
#    'word': 'Lord',
#    'start': 8,
#    'end': 12},
#   {'entity': 'I-PER',
#    'score': 0.95983505,
#    'index': 4,
#    'word': 'V',
#    'start': 13,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.6803472,
#    'index': 5,
#    'word': '##ader',
#    'start': 14,
#    'end': 18}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.7602301,
#    'index': 1,
#    'word': 'Dan',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.8874101,
#    'index': 2,
#    'word': '##to',
#    'start': 3,
#    'end': 5},
#   {'entity': 'I-ORG',
#    'score': 0.71274394,
#    'index': 3,
#    'word': '##oi',
#    'start': 5,
#    'end': 7},
#   {'entity': 'I-ORG',
#    'score': 0.8934881,
#    'index': 4,
#    'word': '##ne',
#    'start': 7,
#    'end': 9}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9752588,
#    'index': 6,
#    'word': 'Rebel',
#    'start': 23,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.82653356,
#    'index': 8,
#    'word': 'Force',
#    'start': 34,
#    'end': 39}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9890856,
#    'index': 9,
#    'word': 'W',
#    'start': 25,
#    'end': 26},
#   {'entity': 'I-MISC',
#    'score': 0.82246596,
#    'index': 10,
#    'word': '##ook',
#    'start': 26,
#    'end': 29},
#   {'entity': 'I-MISC',
#    'score': 0.76041377,
#    'index': 11,
#    'word': '##ie',
#    'start': 29,
#    'end': 31},
#   {'entity': 'I-MISC',
#    'score': 0.56567484,
#    'index': 12,
#    'word': '##e',
#    'start': 31,
#    'end': 32}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.33199635,
#    'index': 2,
#    'word': '##ook',
#    'start': 1,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.84066975,
#    'index': 25,
#    'word': 'Force',
#    'start': 106,
#    'end': 111},
#   {'entity': 'I-MISC',
#    'score': 0.731496,
#    'index': 26,
#    'word': 'Kid',
#    'start': 112,
#    'end': 115}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9912642,
#    'index': 13,
#    'word': 'Al',
#    'start': 52,
#    'end': 54},
#   {'entity': 'I-LOC',
#    'score': 0.9913852,
#    'index': 14,
#    'word': '##der',
#    'start': 54,
#    'end': 57},
#   {'entity': 'I-LOC',
#    'score': 0.9907895,
#    'index': 15,
#    'word': '##aan',
#    'start': 57,
#    'end': 60}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.99529016,
#    'index': 6,
#    'word': 'Dan',
#    'start': 29,
#    'end': 32},
#   {'entity': 'I-LOC',
#    'score': 0.7933631,
#    'index': 8,
#    'word': '##oi',
#    'start': 34,
#    'end': 36},
#   {'entity': 'I-LOC',
#    'score': 0.97904795,
#    'index': 9,
#    'word': '##ne',
#    'start': 36,
#    'end': 38}],
#  [{'entity': 'B-MISC',
#    'score': 0.97833794,
#    'index': 7,
#    'word': 'Rebel',
#    'start': 28,
#    'end': 33}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.86542636,
#    'index': 10,
#    'word': 'Rebellion',
#    'start': 50,
#    'end': 59}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.93841636,
#    'index': 9,
#    'word': 'Empire',
#    'start': 20,
#    'end': 26}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9845501,
#    'index': 5,
#    'word': 'Imperial',
#    'start': 8,
#    'end': 16}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9931712,
#    'index': 1,
#    'word': 'Ch',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-PER',
#    'score': 0.6938264,
#    'index': 2,
#    'word': '##ew',
#    'start': 2,
#    'end': 4},
#   {'entity': 'I-PER',
#    'score': 0.43595302,
#    'index': 3,
#    'word': '##ie',
#    'start': 4,
#    'end': 6}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.6502761,
#    'index': 1,
#    'word': 'Clear',
#    'start': 0,
#    'end': 5},
#   {'entity': 'I-LOC',
#    'score': 0.5932279,
#    'index': 2,
#    'word': 'Bay',
#    'start': 6,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.94731736,
#    'index': 13,
#    'word': 'Al',
#    'start': 55,
#    'end': 57},
#   {'entity': 'I-LOC',
#    'score': 0.9768025,
#    'index': 14,
#    'word': '##der',
#    'start': 57,
#    'end': 60},
#   {'entity': 'I-LOC',
#    'score': 0.9045817,
#    'index': 15,
#    'word': '##aan',
#    'start': 60,
#    'end': 63}],
#  [{'entity': 'B-LOC',
#    'score': 0.9893104,
#    'index': 16,
#    'word': 'Mo',
#    'start': 64,
#    'end': 66},
#   {'entity': 'I-LOC',
#    'score': 0.9875229,
#    'index': 17,
#    'word': '##s',
#    'start': 66,
#    'end': 67},
#   {'entity': 'I-LOC',
#    'score': 0.9828038,
#    'index': 18,
#    'word': 'E',
#    'start': 68,
#    'end': 69},
#   {'entity': 'I-LOC',
#    'score': 0.8028885,
#    'index': 19,
#    'word': '##is',
#    'start': 69,
#    'end': 71},
#   {'entity': 'I-LOC',
#    'score': 0.9673458,
#    'index': 20,
#    'word': '##ley',
#    'start': 71,
#    'end': 74}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.97236043,
#    'index': 1,
#    'word': 'TX',
#    'start': 0,
#    'end': 2}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9511135,
#    'index': 9,
#    'word': 'Imperial',
#    'start': 42,
#    'end': 50}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9824631,
#    'index': 16,
#    'word': 'Al',
#    'start': 81,
#    'end': 83},
#   {'entity': 'I-LOC',
#    'score': 0.9859118,
#    'index': 17,
#    'word': '##der',
#    'start': 83,
#    'end': 86},
#   {'entity': 'I-LOC',
#    'score': 0.98556143,
#    'index': 18,
#    'word': '##aan',
#    'start': 86,
#    'end': 89}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.97732055,
#    'index': 2,
#    'word': 'Force',
#    'start': 4,
#    'end': 9}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9935387,
#    'index': 1,
#    'word': 'Ben',
#    'start': 0,
#    'end': 3}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.6877938,
#    'index': 13,
#    'word': 'Le',
#    'start': 44,
#    'end': 46},
#   {'entity': 'I-PER',
#    'score': 0.3199592,
#    'index': 14,
#    'word': '##ia',
#    'start': 46,
#    'end': 48}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9219607,
#    'index': 1,
#    'word': 'Rich',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.49597836,
#    'index': 5,
#    'word': 'Three',
#    'start': 6,
#    'end': 11}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.85380435,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.9342824,
#    'index': 7,
#    'word': 'Luke',
#    'start': 23,
#    'end': 27}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9485075,
#    'index': 6,
#    'word': 'Luke',
#    'start': 27,
#    'end': 31}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99196273,
#    'index': 4,
#    'word': 'Luke',
#    'start': 4,
#    'end': 8},
#   {'entity': 'I-PER',
#    'score': 0.99788994,
#    'index': 5,
#    'word': 'Sky',
#    'start': 9,
#    'end': 12},
#   {'entity': 'I-PER',
#    'score': 0.7886102,
#    'index': 6,
#    'word': '##walk',
#    'start': 12,
#    'end': 16},
#   {'entity': 'I-PER',
#    'score': 0.69507384,
#    'index': 7,
#    'word': '##er',
#    'start': 16,
#    'end': 18}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99753594,
#    'index': 6,
#    'word': 'Ben',
#    'start': 14,
#    'end': 17},
#   {'entity': 'I-PER',
#    'score': 0.9989104,
#    'index': 7,
#    'word': 'Ken',
#    'start': 18,
#    'end': 21},
#   {'entity': 'I-PER',
#    'score': 0.88649255,
#    'index': 8,
#    'word': '##ob',
#    'start': 21,
#    'end': 23},
#   {'entity': 'I-PER',
#    'score': 0.84228987,
#    'index': 9,
#    'word': '##i',
#    'start': 23,
#    'end': 24}],
#  [{'entity': 'B-PER',
#    'score': 0.99900526,
#    'index': 1,
#    'word': 'Ben',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.99944156,
#    'index': 2,
#    'word': 'Ken',
#    'start': 4,
#    'end': 7},
#   {'entity': 'I-PER',
#    'score': 0.9827586,
#    'index': 3,
#    'word': '##ob',
#    'start': 7,
#    'end': 9},
#   {'entity': 'I-PER',
#    'score': 0.9700741,
#    'index': 4,
#    'word': '##i',
#    'start': 9,
#    'end': 10}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9913018,
#    'index': 7,
#    'word': 'O',
#    'start': 15,
#    'end': 16},
#   {'entity': 'I-PER',
#    'score': 0.7793349,
#    'index': 8,
#    'word': '##bi',
#    'start': 16,
#    'end': 18},
#   {'entity': 'I-PER',
#    'score': 0.715739,
#    'index': 9,
#    'word': '-',
#    'start': 18,
#    'end': 19},
#   {'entity': 'I-PER',
#    'score': 0.8330545,
#    'index': 10,
#    'word': 'Wan',
#    'start': 19,
#    'end': 22},
#   {'entity': 'I-PER',
#    'score': 0.9958275,
#    'index': 11,
#    'word': 'Ken',
#    'start': 23,
#    'end': 26},
#   {'entity': 'I-PER',
#    'score': 0.9167009,
#    'index': 12,
#    'word': '##ob',
#    'start': 26,
#    'end': 28},
#   {'entity': 'I-PER',
#    'score': 0.839838,
#    'index': 13,
#    'word': '##i',
#    'start': 28,
#    'end': 29}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.89140993,
#    'index': 7,
#    'word': 'Force',
#    'start': 16,
#    'end': 21}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.98318374,
#    'index': 8,
#    'word': 'Force',
#    'start': 24,
#    'end': 29}],
#  [{'entity': 'B-MISC',
#    'score': 0.9286868,
#    'index': 2,
#    'word': 'Jed',
#    'start': 4,
#    'end': 7},
#   {'entity': 'I-MISC',
#    'score': 0.93036366,
#    'index': 3,
#    'word': '##i',
#    'start': 7,
#    'end': 8}],
#  [{'entity': 'B-PER',
#    'score': 0.9986393,
#    'index': 2,
#    'word': 'Ta',
#    'start': 9,
#    'end': 11},
#   {'entity': 'I-PER',
#    'score': 0.9792172,
#    'index': 3,
#    'word': '##rkin',
#    'start': 11,
#    'end': 15}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.98875207,
#    'index': 1,
#    'word': 'O',
#    'start': 0,
#    'end': 1},
#   {'entity': 'I-PER',
#    'score': 0.77568436,
#    'index': 2,
#    'word': '##bi',
#    'start': 1,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.6110685,
#    'index': 3,
#    'word': '-',
#    'start': 3,
#    'end': 4},
#   {'entity': 'I-PER',
#    'score': 0.81774616,
#    'index': 4,
#    'word': 'Wan',
#    'start': 4,
#    'end': 7}],
#  [{'entity': 'B-ORG',
#    'score': 0.9044927,
#    'index': 1,
#    'word': 'The',
#    'start': 0,
#    'end': 3},
#   {'entity': 'B-ORG',
#    'score': 0.95589393,
#    'index': 2,
#    'word': 'Force',
#    'start': 4,
#    'end': 9}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.86603653,
#    'index': 1,
#    'word': 'Ch',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-MISC',
#    'score': 0.7079552,
#    'index': 2,
#    'word': '##ew',
#    'start': 2,
#    'end': 4},
#   {'entity': 'I-MISC',
#    'score': 0.73746836,
#    'index': 3,
#    'word': '##ie',
#    'start': 4,
#    'end': 6}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.48135614,
#    'index': 13,
#    'word': 'Three',
#    'start': 42,
#    'end': 47}],
#  [{'entity': 'B-ORG',
#    'score': 0.34561256,
#    'index': 1,
#    'word': 'See',
#    'start': 0,
#    'end': 3},
#   {'entity': 'B-ORG',
#    'score': 0.34372798,
#    'index': 3,
#    'word': 'Three',
#    'start': 4,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.3554628,
#    'index': 1,
#    'word': 'Oh',
#    'start': 0,
#    'end': 2}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6742065,
#    'index': 1,
#    'word': 'Help',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.49646726,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.49646726,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.49646726,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.49646726,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-MISC',
#    'score': 0.61749315,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.49646726,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.49646726,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6221929,
#    'index': 1,
#    'word': 'Three',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-ORG',
#    'score': 0.32692483,
#    'index': 3,
#    'word': 'Three',
#    'start': 8,
#    'end': 13}],
#  [{'entity': 'B-ORG',
#    'score': 0.6221929,
#    'index': 1,
#    'word': 'Three',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.3554628,
#    'index': 1,
#    'word': 'Oh',
#    'start': 0,
#    'end': 2}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6221929,
#    'index': 1,
#    'word': 'Three',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6221929,
#    'index': 1,
#    'word': 'Three',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-ORG',
#    'score': 0.43273002,
#    'index': 1,
#    'word': 'Three',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.71603125,
#    'index': 5,
#    'word': 'Three',
#    'start': 17,
#    'end': 22}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.91866857,
#    'index': 4,
#    'word': 'Ch',
#    'start': 13,
#    'end': 15},
#   {'entity': 'I-PER',
#    'score': 0.4522736,
#    'index': 5,
#    'word': '##ew',
#    'start': 15,
#    'end': 17},
#   {'entity': 'I-PER',
#    'score': 0.36136782,
#    'index': 6,
#    'word': '##ie',
#    'start': 17,
#    'end': 19}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.5152134,
#    'index': 3,
#    'word': 'Three',
#    'start': 4,
#    'end': 9},
#   {'entity': 'I-ORG',
#    'score': 0.40603068,
#    'index': 4,
#    'word': '##pio',
#    'start': 9,
#    'end': 12}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9594922,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6742065,
#    'index': 1,
#    'word': 'Help',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.7409776,
#    'index': 9,
#    'word': 'Art',
#    'start': 42,
#    'end': 45},
#   {'entity': 'I-ORG',
#    'score': 0.59669536,
#    'index': 10,
#    'word': '##oo',
#    'start': 45,
#    'end': 47}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.814545,
#    'index': 5,
#    'word': 'Al',
#    'start': 20,
#    'end': 22},
#   {'entity': 'I-LOC',
#    'score': 0.69174075,
#    'index': 7,
#    'word': '##aan',
#    'start': 25,
#    'end': 28}],
#  [{'entity': 'B-LOC',
#    'score': 0.98936903,
#    'index': 6,
#    'word': 'Ya',
#    'start': 30,
#    'end': 32},
#   {'entity': 'I-LOC',
#    'score': 0.9666414,
#    'index': 7,
#    'word': '##vin',
#    'start': 32,
#    'end': 35}],
#  [{'entity': 'B-MISC',
#    'score': 0.90693927,
#    'index': 2,
#    'word': 'Rebel',
#    'start': 4,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.7283746,
#    'index': 13,
#    'word': 'T',
#    'start': 35,
#    'end': 36}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6567175,
#    'index': 4,
#    'word': 'Force',
#    'start': 12,
#    'end': 17}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.90344656,
#    'index': 5,
#    'word': 'Rebel',
#    'start': 18,
#    'end': 23}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.91859484,
#    'index': 7,
#    'word': 'Ken',
#    'start': 23,
#    'end': 26},
#   {'entity': 'I-PER',
#    'score': 0.4491658,
#    'index': 8,
#    'word': '##ob',
#    'start': 26,
#    'end': 28},
#   {'entity': 'B-MISC',
#    'score': 0.47083133,
#    'index': 19,
#    'word': 'Rebellion',
#    'start': 66,
#    'end': 75}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.88099676,
#    'index': 4,
#    'word': 'Ben',
#    'start': 12,
#    'end': 15}],
#  [{'entity': 'B-PER',
#    'score': 0.49646726,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.4870429,
#    'index': 1,
#    'word': 'Big',
#    'start': 0,
#    'end': 3}],
#  [{'entity': 'B-PER',
#    'score': 0.9920288,
#    'index': 8,
#    'word': 'Luke',
#    'start': 21,
#    'end': 25},
#   {'entity': 'I-PER',
#    'score': 0.99775213,
#    'index': 9,
#    'word': 'Sky',
#    'start': 26,
#    'end': 29},
#   {'entity': 'I-PER',
#    'score': 0.5983359,
#    'index': 10,
#    'word': '##walk',
#    'start': 29,
#    'end': 33},
#   {'entity': 'I-PER',
#    'score': 0.40554562,
#    'index': 11,
#    'word': '##er',
#    'start': 33,
#    'end': 35}],
#  [{'entity': 'B-MISC',
#    'score': 0.98232377,
#    'index': 8,
#    'word': 'Inc',
#    'start': 33,
#    'end': 36},
#   {'entity': 'I-MISC',
#    'score': 0.9735165,
#    'index': 9,
#    'word': '##om',
#    'start': 36,
#    'end': 38},
#   {'entity': 'I-MISC',
#    'score': 0.4847274,
#    'index': 10,
#    'word': 'T',
#    'start': 39,
#    'end': 40},
#   {'entity': 'I-MISC',
#    'score': 0.95194995,
#    'index': 11,
#    'word': '-',
#    'start': 40,
#    'end': 41},
#   {'entity': 'I-MISC',
#    'score': 0.7141772,
#    'index': 12,
#    'word': 'sixty',
#    'start': 41,
#    'end': 46},
#   {'entity': 'I-MISC',
#    'score': 0.7297862,
#    'index': 13,
#    'word': '-',
#    'start': 46,
#    'end': 47},
#   {'entity': 'I-MISC',
#    'score': 0.7083535,
#    'index': 14,
#    'word': 'five',
#    'start': 47,
#    'end': 51}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.987463,
#    'index': 30,
#    'word': 'Luke',
#    'start': 125,
#    'end': 129}],
#  [{'entity': 'B-ORG',
#    'score': 0.54525155,
#    'index': 1,
#    'word': 'Death',
#    'start': 0,
#    'end': 5},
#   {'entity': 'I-MISC',
#    'score': 0.80756986,
#    'index': 2,
#    'word': 'Star',
#    'start': 6,
#    'end': 10}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.996425,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.99366486,
#    'index': 2,
#    'word': 'Ten',
#    'start': 4,
#    'end': 7}],
#  [{'entity': 'B-ORG',
#    'score': 0.9800654,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.9583974,
#    'index': 2,
#    'word': 'Seven',
#    'start': 4,
#    'end': 9}],
#  [{'entity': 'B-ORG',
#    'score': 0.7703737,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.50480306,
#    'index': 2,
#    'word': 'Three',
#    'start': 4,
#    'end': 9}],
#  [{'entity': 'B-ORG',
#    'score': 0.851368,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.7314643,
#    'index': 2,
#    'word': 'Six',
#    'start': 4,
#    'end': 7}],
#  [{'entity': 'B-ORG',
#    'score': 0.77084833,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.625104,
#    'index': 2,
#    'word': 'Nine',
#    'start': 4,
#    'end': 8}],
#  [{'entity': 'B-ORG',
#    'score': 0.6038807,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.41879255,
#    'index': 2,
#    'word': 'Two',
#    'start': 4,
#    'end': 7}],
#  [{'entity': 'B-ORG',
#    'score': 0.99942976,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.99835455,
#    'index': 2,
#    'word': 'Eleven',
#    'start': 4,
#    'end': 10}],
#  [{'entity': 'B-ORG',
#    'score': 0.84070545,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.5296444,
#    'index': 2,
#    'word': 'Five',
#    'start': 4,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.414592,
#    'index': 4,
#    'word': 'Red',
#    'start': 11,
#    'end': 14}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.7679593,
#    'index': 3,
#    'word': 'Red',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-ORG',
#    'score': 0.92584145,
#    'index': 4,
#    'word': 'Five',
#    'start': 12,
#    'end': 16}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.8743385,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-MISC',
#    'score': 0.98083395,
#    'index': 9,
#    'word': 'Rebel',
#    'start': 38,
#    'end': 43}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.96234983,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9387977,
#    'index': 6,
#    'word': 'Big',
#    'start': 22,
#    'end': 25}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99193865,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9686074,
#    'index': 10,
#    'word': 'Art',
#    'start': 28,
#    'end': 31},
#   {'entity': 'I-PER',
#    'score': 0.63902074,
#    'index': 11,
#    'word': '##oo',
#    'start': 31,
#    'end': 33},
#   {'entity': 'I-PER',
#    'score': 0.40935102,
#    'index': 13,
#    'word': 'Six',
#    'start': 38,
#    'end': 41},
#   {'entity': 'B-MISC',
#    'score': 0.4181236,
#    'index': 20,
#    'word': 'Red',
#    'start': 58,
#    'end': 61},
#   {'entity': 'I-PER',
#    'score': 0.43229115,
#    'index': 21,
#    'word': 'Five',
#    'start': 62,
#    'end': 66}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.41067415,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.38941786,
#    'index': 2,
#    'word': 'Five',
#    'start': 4,
#    'end': 8}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9873273,
#    'index': 1,
#    'word': 'We',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-PER',
#    'score': 0.49164128,
#    'index': 2,
#    'word': '##dge',
#    'start': 2,
#    'end': 5}],
#  [{'entity': 'B-ORG',
#    'score': 0.5753062,
#    'index': 4,
#    'word': 'Red',
#    'start': 21,
#    'end': 24},
#   {'entity': 'I-ORG',
#    'score': 0.7155666,
#    'index': 5,
#    'word': 'Leader',
#    'start': 25,
#    'end': 31}],
#  [{'entity': 'B-PER',
#    'score': 0.75733584,
#    'index': 3,
#    'word': 'Gold',
#    'start': 8,
#    'end': 12}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.57451653,
#    'index': 5,
#    'word': 'Death',
#    'start': 20,
#    'end': 25},
#   {'entity': 'I-MISC',
#    'score': 0.62855184,
#    'index': 6,
#    'word': 'Star',
#    'start': 26,
#    'end': 30}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.92203814,
#    'index': 10,
#    'word': 'T',
#    'start': 33,
#    'end': 34},
#   {'entity': 'B-PER',
#    'score': 0.47226936,
#    'index': 11,
#    'word': '##ire',
#    'start': 34,
#    'end': 37}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9968905,
#    'index': 3,
#    'word': 'Red',
#    'start': 11,
#    'end': 14},
#   {'entity': 'I-ORG',
#    'score': 0.9962399,
#    'index': 4,
#    'word': 'Group',
#    'start': 15,
#    'end': 20},
#   {'entity': 'I-ORG',
#    'score': 0.99705976,
#    'index': 5,
#    'word': 'Ren',
#    'start': 21,
#    'end': 24},
#   {'entity': 'I-ORG',
#    'score': 0.9893958,
#    'index': 6,
#    'word': '##dez',
#    'start': 24,
#    'end': 27},
#   {'entity': 'I-ORG',
#    'score': 0.99256563,
#    'index': 7,
#    'word': '##vous',
#    'start': 27,
#    'end': 31}],
#  [{'entity': 'B-ORG',
#    'score': 0.8585394,
#    'index': 3,
#    'word': 'Red',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-ORG',
#    'score': 0.88217145,
#    'index': 4,
#    'word': 'Two',
#    'start': 12,
#    'end': 15}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.8476621,
#    'index': 7,
#    'word': 'Red',
#    'start': 16,
#    'end': 19},
#   {'entity': 'I-MISC',
#    'score': 0.8914558,
#    'index': 8,
#    'word': 'Leader',
#    'start': 20,
#    'end': 26}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9840179,
#    'index': 3,
#    'word': 'Big',
#    'start': 11,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.34907156,
#    'index': 4,
#    'word': '##gs',
#    'start': 14,
#    'end': 16},
#   {'entity': 'B-PER',
#    'score': 0.9894879,
#    'index': 8,
#    'word': 'Luke',
#    'start': 32,
#    'end': 36},
#   {'entity': 'B-LOC',
#    'score': 0.8343471,
#    'index': 15,
#    'word': 'Be',
#    'start': 56,
#    'end': 58},
#   {'entity': 'I-LOC',
#    'score': 0.440855,
#    'index': 16,
#    'word': '##gg',
#    'start': 58,
#    'end': 60},
#   {'entity': 'I-LOC',
#    'score': 0.3875554,
#    'index': 17,
#    'word': '##ar',
#    'start': 60,
#    'end': 62},
#   {'entity': 'I-LOC',
#    'score': 0.8105505,
#    'index': 18,
#    'word': "'",
#    'start': 62,
#    'end': 63},
#   {'entity': 'I-LOC',
#    'score': 0.8020776,
#    'index': 19,
#    'word': 's',
#    'start': 63,
#    'end': 64},
#   {'entity': 'I-LOC',
#    'score': 0.7818872,
#    'index': 20,
#    'word': 'Canyon',
#    'start': 65,
#    'end': 71}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99595535,
#    'index': 1,
#    'word': 'Art',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.80984205,
#    'index': 2,
#    'word': '##oo',
#    'start': 3,
#    'end': 5}],
#  [],
#  [],
#  [],
#  ...]

# %%
reconstructed_loc = []
current_entity = ''

for sent in docs:
    if len(sent) > 0:
        for entity in sent: 
            word = entity['word']
            entity_tag = entity['entity']
            
            if entity_tag == 'B-LOC':
                if current_entity:
                    if word.startswith('##'):
                        current_entity += word[2:]
                    else:
                        reconstructed_loc.append(current_entity)
                        current_entity = word
                else:
                    current_entity = word
            elif entity_tag == 'I-LOC':
                current_entity += word[2:] if word.startswith('##') else f" {word}"
            
if current_entity:
    reconstructed_loc.append(current_entity)

# %%
reconstructed_loc
# Out:
# ['Kessel',
#  'Alderaan',
#  'Anchorhead',
#  'Toshi Station',
#  'Empire',
#  'Anchorhead',
#  'Jundland Wastes',
#  'Old Republic',
#  'Alderaan',
#  'Alaan',
#  'Alaan',
#  'Alderaan',
#  'Alderaan',
#  'Alderaania',
#  'Alaan',
#  'Alderaan',
#  'Alderaan',
#  'Dantooine',
#  'Alderaan',
#  'Danoine',
#  'Clear Bay',
#  'Alderaan',
#  'Mos Eisley',
#  'TX',
#  'Alderaan',
#  'Alaan',
#  'Yavin',
#  "Beggar ' s Canyon We",
#  'Echo Base',
#  'Empire',
#  'Hoth',
#  'Empire',
#  'Art',
#  'Mu',
#  'Ha',
#  'Empire',
#  'Empireiaia',
#  'Jabba the Hutt',
#  'Tatooineoo',
#  'J',
#  'Dune Sea',
#  'Carkoon',
#  'Moon of',
#  'Endor',
#  'Endor',
#  'Sullustia',
#  'Endor Moonia',
#  'Endor']

# %%
reconstructed_entities = []
current_entity = ''

for sent in docs:
    if len(sent) > 0:
        for entity in sent: 
            word = entity['word']
            entity_tag = entity['entity']
            
            if entity_tag == 'B-PER':
                if current_entity:
                    if word.startswith('##'):
                        current_entity += word[2:]
                    else:
                        reconstructed_entities.append(current_entity)
                        current_entity = word
                else:
                    current_entity = word
            elif entity_tag == 'I-PER':
                current_entity += word[2:] if word.startswith('##') else f" {word}"
            
if current_entity:
    reconstructed_entities.append(current_entity)

# %%
reconstructed_entities
# Out:
# ['Artoo',
#  'Detoo Vader',
#  'Wormie',
#  'Big',
#  'Biggs Darklighter',
#  'Lord Vader',
#  'Lord Vader',
#  'Luke',
#  'Mos Eisley',
#  'Luke',
#  'Artoo',
#  'Det',
#  'Luke',
#  'Luke',
#  'Owen',
#  'Owen',
#  'Luke',
#  'See Threepio',
#  'Obi - Wan Kenobi',
#  'Obi - Wan Kenobi',
#  'Ben Kenobi',
#  'Luke',
#  'Luke',
#  'Ben',
#  'Obi - Wan',
#  'Owen',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Ben Kenobi',
#  'Sir Sure Luke',
#  'Obi - Wan Kenob',
#  'Ben',
#  'Ben Kenob',
#  'Oh',
#  'Obi Wan Kenobi',
#  'Obi Wan',
#  'Darth Vader',
#  'Kenobi',
#  'Vader Vader',
#  'Art',
#  'Threepio',
#  'J Owen Be',
#  'Owen',
#  'Chewbacca',
#  'Han Solo',
#  'Chewie',
#  'Jabba',
#  'Jabba',
#  'Jabba',
#  'Jab',
#  'Le Luke',
#  'Han You',
#  'Greedo',
#  'Han',
#  'Han',
#  'Han Jabba',
#  'Chewie Oh',
#  'Tarkin Charming',
#  'Leia',
#  'Lord Vader',
#  'Chewie',
#  'Ben',
#  'Leia',
#  'Rich',
#  'Three',
#  'Han Luke',
#  'Luke',
#  'Luke Skywalker',
#  'Ben Kenobi',
#  'Ben Kenobi',
#  'Obi - Wan Kenobi',
#  'Tarkin',
#  'Obi - Wan',
#  'Three',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Three',
#  'Chewie',
#  'Three',
#  'Luke',
#  'Kenob',
#  'Ben',
#  'Luke',
#  'Luke Skywalker',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Big',
#  'Luke',
#  'Artoo Six Five',
#  'Wedge',
#  'Gold',
#  'Tire',
#  'Biggs',
#  'Luke',
#  'Artoo',
#  'Artoo',
#  'Luke',
#  'Luke Nothing',
#  'Artoo',
#  'Luke',
#  'Luke',
#  'Luke',
#  'Han',
#  'Solo',
#  'Skywalker',
#  'Han Skywalker Luke Leia',
#  'Artoo',
#  'Luke',
#  'Luke',
#  'Ben',
#  'Yoda Ben',
#  'Ben',
#  'Luke',
#  'Luke',
#  'Ben',
#  'Ben',
#  'Yoda Solo',
#  'Luke Artoo',
#  'Rieekan',
#  'Luke',
#  'Skywalk',
#  'Chewie',
#  'Ozzel',
#  'Lord Vader',
#  'Luke Steady',
#  'Hobbie',
#  'Da',
#  'Ho Solo',
#  'Artoo',
#  'Artoo Oh',
#  'Yoda',
#  'Yoda',
#  'Yoda',
#  'Chewie Lord Vader',
#  'Luke Skywalker',
#  'Obi - Wan',
#  'Skywalk',
#  'Yo',
#  'Yoda',
#  'Ah Oh',
#  'Ben Ready',
#  'Vader',
#  'Needa No',
#  'Lord Vader',
#  'Solo',
#  'Lando Calrissian',
#  'Leia',
#  'Luke',
#  'Han',
#  'Le',
#  'Yoda',
#  'Yoda',
#  'Luke',
#  'Vader',
#  'Patience',
#  'Han',
#  'Le',
#  'Vader',
#  'Artoo Luke Strong',
#  'V',
#  'Threepio',
#  'Lando',
#  'Lando',
#  'Lando V Solo',
#  'Sky',
#  'Lord Vader',
#  'Lando',
#  'Vader',
#  'Leia',
#  'Chewie',
#  'Han',
#  'Vader',
#  'Vader',
#  'Skywalker',
#  'Luke',
#  'Lord Vader Vader',
#  'Skywalker',
#  'Vader Solo',
#  'Chew',
#  'Chewie',
#  'Sky',
#  'Skywalker',
#  'Luke',
#  'Luke',
#  'Han',
#  'Han',
#  'Han',
#  'Chewie Solo',
#  'Obi - Wan',
#  'Lando Calrissian',
#  'Leia',
#  'Obi - Wan',
#  'Obi - Wan',
#  'Luke',
#  'Ben',
#  'Ben Ben',
#  'Luke',
#  'Luke',
#  'Chewie',
#  'Vader',
#  'Luke',
#  'Chewie',
#  'Art',
#  'Detoo Luke Chew',
#  'Vader',
#  'Luke',
#  'Artoo Luke',
#  'Jabba',
#  'Chewie',
#  'Lord Vader V',
#  'Jabba',
#  'Art Luke',
#  'Artoo Detoo',
#  'Seethreepiow',
#  'Art Luke',
#  'Jabba',
#  'Artoo',
#  'Artoo Solo',
#  'Artoo Luke',
#  'See Threepio',
#  'Artoo',
#  'Da Ea',
#  'Chewbacca',
#  'Jabbaab',
#  'Jabba',
#  'Jab',
#  'Chewie',
#  'Luke',
#  'Luke',
#  'Jabbaab Luke',
#  'Luke Skywalker Solo Luke',
#  'Ba',
#  'Solo',
#  'Luke',
#  'Oh',
#  'Chewie',
#  'Lando',
#  'Sa',
#  'Threepio Jabba',
#  'Chewie',
#  'Han',
#  'Chew Fe Fe',
#  'Land',
#  'Lando',
#  'Chewie',
#  'Chewie',
#  'Chewie',
#  'Artoo',
#  'Art',
#  'Yoda',
#  'Vader',
#  'Vader Yoda',
#  'Darth Vader',
#  'Yoda',
#  'Luke',
#  'Luke',
#  'Yoda',
#  'Vader',
#  'Anakin Skywalker',
#  'Darth Vader',
#  'Luke',
#  'Anakin',
#  'Vader',
#  'Darth Vader',
#  'Yoda',
#  'Leia',
#  'Leia',
#  'Organ',
#  'Leia',
#  'Ackbar',
#  'Calrissian',
#  'Madine',
#  'Solo',
#  'Luke',
#  'Chewie',
#  'Skywalker',
#  'Vader',
#  'Chewie',
#  'Luke',
#  'Le',
#  'Luke',
#  'Luke',
#  'Le',
#  'Chew',
#  'Han Yeah Artoo Wha',
#  'Han Chewie Oh',
#  'Leia Luke',
#  'Luke Leia',
#  'Luke Vader',
#  'Luke',
#  'Leia',
#  'Luke',
#  'Luke',
#  'Anakin Skywalker',
#  'Obi - Wan',
#  'Master',
#  'Red Leader',
#  'Gray Leader',
#  'Artoo',
#  'Artoo',
#  'Han',
#  'Artoo',
#  'Obi - Wan',
#  'Luke',
#  'Lando']

# %%
for sentence in script_sentences:
    doc = ner_pipeline(sentence)

# %%
ner_output = []
for sent in doc:
    if len(sent) > 0:
        if 'PER' in sent['entity']:
            ner_output.append((sent['entity'],sent['word']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       2 for sent in doc:
#       3     if len(sent) > 0:
# ----> 4         if 'PER' in sent['entity']:
#       5             ner_output.append((sent['entity'],sent['word']))
#
# TypeError: list indices must be integers or slices, not str

# %%
dict_ = {'entity': 'B-ORG',
   'score': 0.7749182,
   'index': 1,
   'word': 'Art',
   'start': 0,
   'end': 3}

# %%
'ORG' in dict_['entity']
# Out:
# True

# %%
doc
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.7749182,
#    'index': 1,
#    'word': 'Art',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.5198912,
#    'index': 2,
#    'word': '##oo',
#    'start': 3,
#    'end': 5}],
#  [{'entity': 'B-PER',
#    'score': 0.61526746,
#    'index': 1,
#    'word': 'Art',
#    'start': 0,
#    'end': 3},
#   {'entity': 'B-PER',
#    'score': 0.9085649,
#    'index': 4,
#    'word': 'Det',
#    'start': 6,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.99421966,
#    'index': 12,
#    'word': 'Ke',
#    'start': 36,
#    'end': 38},
#   {'entity': 'I-LOC',
#    'score': 0.7407636,
#    'index': 13,
#    'word': '##ssel',
#    'start': 38,
#    'end': 42}],
#  [{'entity': 'B-ORG',
#    'score': 0.59782326,
#    'index': 5,
#    'word': 'Death',
#    'start': 18,
#    'end': 23},
#   {'entity': 'I-ORG',
#    'score': 0.9461144,
#    'index': 6,
#    'word': 'Star',
#    'start': 24,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9931478,
#    'index': 4,
#    'word': 'V',
#    'start': 12,
#    'end': 13},
#   {'entity': 'I-PER',
#    'score': 0.6627077,
#    'index': 5,
#    'word': '##ader',
#    'start': 13,
#    'end': 17}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9969241,
#    'index': 4,
#    'word': 'W',
#    'start': 12,
#    'end': 13},
#   {'entity': 'B-PER',
#    'score': 0.9007494,
#    'index': 5,
#    'word': '##orm',
#    'start': 13,
#    'end': 16}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.97960025,
#    'index': 6,
#    'word': 'The',
#    'start': 25,
#    'end': 28},
#   {'entity': 'I-ORG',
#    'score': 0.96362275,
#    'index': 7,
#    'word': 'Academy',
#    'start': 29,
#    'end': 36}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.91253453,
#    'index': 4,
#    'word': 'The',
#    'start': 14,
#    'end': 17},
#   {'entity': 'I-MISC',
#    'score': 0.8738102,
#    'index': 5,
#    'word': 'Rand',
#    'start': 18,
#    'end': 22},
#   {'entity': 'I-MISC',
#    'score': 0.9893143,
#    'index': 6,
#    'word': 'E',
#    'start': 23,
#    'end': 24},
#   {'entity': 'I-MISC',
#    'score': 0.9055003,
#    'index': 7,
#    'word': '##c',
#    'start': 24,
#    'end': 25},
#   {'entity': 'I-MISC',
#    'score': 0.72904754,
#    'index': 8,
#    'word': '##liptic',
#    'start': 25,
#    'end': 31}],
#  [{'entity': 'B-PER',
#    'score': 0.99433196,
#    'index': 3,
#    'word': 'Big',
#    'start': 11,
#    'end': 14},
#   {'entity': 'B-PER',
#    'score': 0.9210894,
#    'index': 4,
#    'word': '##gs',
#    'start': 14,
#    'end': 16},
#   {'entity': 'I-PER',
#    'score': 0.9916727,
#    'index': 5,
#    'word': 'Dark',
#    'start': 17,
#    'end': 21},
#   {'entity': 'I-PER',
#    'score': 0.8615437,
#    'index': 6,
#    'word': '##light',
#    'start': 21,
#    'end': 26}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.93403953,
#    'index': 28,
#    'word': 'Lord',
#    'start': 103,
#    'end': 107},
#   {'entity': 'I-PER',
#    'score': 0.9564392,
#    'index': 29,
#    'word': 'V',
#    'start': 108,
#    'end': 109},
#   {'entity': 'I-PER',
#    'score': 0.9582078,
#    'index': 30,
#    'word': '##ader',
#    'start': 109,
#    'end': 113}],
#  [{'entity': 'B-ORG',
#    'score': 0.94776756,
#    'index': 8,
#    'word': 'Imperial',
#    'start': 20,
#    'end': 28},
#   {'entity': 'B-ORG',
#    'score': 0.8019289,
#    'index': 9,
#    'word': 'Senate',
#    'start': 29,
#    'end': 35},
#   {'entity': 'B-LOC',
#    'score': 0.99908304,
#    'index': 15,
#    'word': 'Al',
#    'start': 63,
#    'end': 65},
#   {'entity': 'I-LOC',
#    'score': 0.98472124,
#    'index': 16,
#    'word': '##der',
#    'start': 65,
#    'end': 68},
#   {'entity': 'I-LOC',
#    'score': 0.9936115,
#    'index': 17,
#    'word': '##aan',
#    'start': 68,
#    'end': 71},
#   {'entity': 'B-ORG',
#    'score': 0.99682957,
#    'index': 28,
#    'word': 'Rebel',
#    'start': 97,
#    'end': 102},
#   {'entity': 'I-ORG',
#    'score': 0.995478,
#    'index': 29,
#    'word': 'Alliance',
#    'start': 103,
#    'end': 111}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9977252,
#    'index': 11,
#    'word': 'Rebel',
#    'start': 43,
#    'end': 48}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.7156246,
#    'index': 2,
#    'word': 'V',
#    'start': 5,
#    'end': 6},
#   {'entity': 'I-PER',
#    'score': 0.8607946,
#    'index': 3,
#    'word': '##ader',
#    'start': 6,
#    'end': 10}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.74102503,
#    'index': 19,
#    'word': 'Luke',
#    'start': 68,
#    'end': 72}],
#  [{'entity': 'B-ORG',
#    'score': 0.55315953,
#    'index': 13,
#    'word': 'Mo',
#    'start': 46,
#    'end': 48},
#   {'entity': 'I-ORG',
#    'score': 0.31382343,
#    'index': 14,
#    'word': '##s',
#    'start': 48,
#    'end': 49},
#   {'entity': 'I-ORG',
#    'score': 0.75797427,
#    'index': 15,
#    'word': 'E',
#    'start': 50,
#    'end': 51},
#   {'entity': 'I-ORG',
#    'score': 0.6917942,
#    'index': 16,
#    'word': '##is',
#    'start': 51,
#    'end': 53},
#   {'entity': 'I-ORG',
#    'score': 0.6234406,
#    'index': 17,
#    'word': '##ley',
#    'start': 53,
#    'end': 56},
#   {'entity': 'I-ORG',
#    'score': 0.5708114,
#    'index': 18,
#    'word': 'Look',
#    'start': 57,
#    'end': 61}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.76344043,
#    'index': 2,
#    'word': 'Luke',
#    'start': 5,
#    'end': 9}],
#  [{'entity': 'B-ORG',
#    'score': 0.951703,
#    'index': 7,
#    'word': 'Academy',
#    'start': 27,
#    'end': 34}],
#  [{'entity': 'B-MISC',
#    'score': 0.41034427,
#    'index': 17,
#    'word': 'Rebellion',
#    'start': 65,
#    'end': 74}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9544468,
#    'index': 15,
#    'word': 'Best',
#    'start': 53,
#    'end': 57}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9642516,
#    'index': 8,
#    'word': 'Academy',
#    'start': 32,
#    'end': 39}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6139904,
#    'index': 10,
#    'word': 'Sand',
#    'start': 41,
#    'end': 45},
#   {'entity': 'I-MISC',
#    'score': 0.5477103,
#    'index': 11,
#    'word': 'People',
#    'start': 46,
#    'end': 52},
#   {'entity': 'B-LOC',
#    'score': 0.9955966,
#    'index': 26,
#    'word': 'An',
#    'start': 108,
#    'end': 110},
#   {'entity': 'I-LOC',
#    'score': 0.9960737,
#    'index': 27,
#    'word': '##chor',
#    'start': 110,
#    'end': 114},
#   {'entity': 'I-LOC',
#    'score': 0.99897027,
#    'index': 28,
#    'word': '##head',
#    'start': 114,
#    'end': 118}],
#  [{'entity': 'B-MISC',
#    'score': 0.544964,
#    'index': 10,
#    'word': 'Sand',
#    'start': 44,
#    'end': 48},
#   {'entity': 'I-MISC',
#    'score': 0.6026625,
#    'index': 11,
#    'word': 'People',
#    'start': 49,
#    'end': 55}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.37549937,
#    'index': 2,
#    'word': 'Empire',
#    'start': 4,
#    'end': 10}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.34181547,
#    'index': 4,
#    'word': 'Art',
#    'start': 13,
#    'end': 16},
#   {'entity': 'I-MISC',
#    'score': 0.448378,
#    'index': 5,
#    'word': '##oo',
#    'start': 16,
#    'end': 18},
#   {'entity': 'B-PER',
#    'score': 0.30919325,
#    'index': 7,
#    'word': 'Det',
#    'start': 19,
#    'end': 22}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.68419296,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.97084177,
#    'index': 10,
#    'word': 'Bo',
#    'start': 31,
#    'end': 33},
#   {'entity': 'I-MISC',
#    'score': 0.55871594,
#    'index': 11,
#    'word': '##cc',
#    'start': 33,
#    'end': 35},
#   {'entity': 'I-MISC',
#    'score': 0.8399551,
#    'index': 12,
#    'word': '##e',
#    'start': 35,
#    'end': 36}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9921858,
#    'index': 4,
#    'word': 'Luke',
#    'start': 12,
#    'end': 16},
#   {'entity': 'B-LOC',
#    'score': 0.9788542,
#    'index': 10,
#    'word': 'To',
#    'start': 38,
#    'end': 40},
#   {'entity': 'B-LOC',
#    'score': 0.93479365,
#    'index': 11,
#    'word': '##shi',
#    'start': 40,
#    'end': 43},
#   {'entity': 'I-LOC',
#    'score': 0.9965474,
#    'index': 12,
#    'word': 'Station',
#    'start': 44,
#    'end': 51}],
#  [{'entity': 'B-PER',
#    'score': 0.94998145,
#    'index': 5,
#    'word': 'Owen',
#    'start': 20,
#    'end': 24}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9277744,
#    'index': 5,
#    'word': 'Owen',
#    'start': 20,
#    'end': 24}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.5198432,
#    'index': 15,
#    'word': 'Luke',
#    'start': 47,
#    'end': 51}],
#  [{'entity': 'B-MISC',
#    'score': 0.680156,
#    'index': 4,
#    'word': 'See',
#    'start': 9,
#    'end': 12},
#   {'entity': 'B-PER',
#    'score': 0.53977984,
#    'index': 6,
#    'word': 'Three',
#    'start': 13,
#    'end': 18}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.70724034,
#    'index': 12,
#    'word': 'Rebellion',
#    'start': 44,
#    'end': 53}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9387181,
#    'index': 12,
#    'word': 'O',
#    'start': 45,
#    'end': 46},
#   {'entity': 'B-PER',
#    'score': 0.5163289,
#    'index': 13,
#    'word': '##bi',
#    'start': 46,
#    'end': 48},
#   {'entity': 'I-PER',
#    'score': 0.6392416,
#    'index': 15,
#    'word': 'Wan',
#    'start': 49,
#    'end': 52},
#   {'entity': 'I-PER',
#    'score': 0.4120031,
#    'index': 16,
#    'word': 'Ken',
#    'start': 53,
#    'end': 56},
#   {'entity': 'I-PER',
#    'score': 0.6286444,
#    'index': 17,
#    'word': '##ob',
#    'start': 56,
#    'end': 58},
#   {'entity': 'B-PER',
#    'score': 0.5817041,
#    'index': 19,
#    'word': 'O',
#    'start': 60,
#    'end': 61},
#   {'entity': 'B-PER',
#    'score': 0.4071663,
#    'index': 22,
#    'word': 'Wan',
#    'start': 64,
#    'end': 67},
#   {'entity': 'I-PER',
#    'score': 0.8770809,
#    'index': 23,
#    'word': 'Ken',
#    'start': 68,
#    'end': 71},
#   {'entity': 'I-PER',
#    'score': 0.6270884,
#    'index': 24,
#    'word': '##ob',
#    'start': 71,
#    'end': 73}],
#  [{'entity': 'B-PER',
#    'score': 0.99906677,
#    'index': 7,
#    'word': 'Ben',
#    'start': 25,
#    'end': 28},
#   {'entity': 'I-PER',
#    'score': 0.9979747,
#    'index': 8,
#    'word': 'Ken',
#    'start': 29,
#    'end': 32},
#   {'entity': 'I-PER',
#    'score': 0.99162334,
#    'index': 9,
#    'word': '##ob',
#    'start': 32,
#    'end': 34}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9862521,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.7465535,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.97751117,
#    'index': 8,
#    'word': 'Ben',
#    'start': 35,
#    'end': 38}],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.99622345,
#    'index': 12,
#    'word': 'An',
#    'start': 46,
#    'end': 48},
#   {'entity': 'I-LOC',
#    'score': 0.96562684,
#    'index': 13,
#    'word': '##chor',
#    'start': 48,
#    'end': 52},
#   {'entity': 'I-LOC',
#    'score': 0.9985526,
#    'index': 14,
#    'word': '##head',
#    'start': 52,
#    'end': 56}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9724123,
#    'index': 5,
#    'word': 'O',
#    'start': 17,
#    'end': 18},
#   {'entity': 'B-PER',
#    'score': 0.9626501,
#    'index': 6,
#    'word': '##bi',
#    'start': 18,
#    'end': 20},
#   {'entity': 'B-PER',
#    'score': 0.5483283,
#    'index': 8,
#    'word': 'Wan',
#    'start': 21,
#    'end': 24}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9440372,
#    'index': 8,
#    'word': 'Academy',
#    'start': 27,
#    'end': 34}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99177915,
#    'index': 1,
#    'word': 'Owen',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9950896,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.53820467,
#    'index': 12,
#    'word': 'Sand',
#    'start': 42,
#    'end': 46},
#   {'entity': 'I-MISC',
#    'score': 0.9450871,
#    'index': 13,
#    'word': 'People',
#    'start': 47,
#    'end': 53}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.7158052,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.9891936,
#    'index': 2,
#    'word': 'Luke',
#    'start': 3,
#    'end': 7}],
#  [{'entity': 'B-PER',
#    'score': 0.9862521,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.9862521,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99415934,
#    'index': 4,
#    'word': 'Luke',
#    'start': 14,
#    'end': 18}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9987741,
#    'index': 2,
#    'word': 'Ben',
#    'start': 4,
#    'end': 7},
#   {'entity': 'I-PER',
#    'score': 0.99883264,
#    'index': 3,
#    'word': 'Ken',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-PER',
#    'score': 0.97950155,
#    'index': 4,
#    'word': '##ob',
#    'start': 11,
#    'end': 13},
#   {'entity': 'B-PER',
#    'score': 0.7777636,
#    'index': 13,
#    'word': 'Sure',
#    'start': 57,
#    'end': 61}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.72078204,
#    'index': 4,
#    'word': 'Master',
#    'start': 14,
#    'end': 20},
#   {'entity': 'B-PER',
#    'score': 0.6697725,
#    'index': 5,
#    'word': 'Luke',
#    'start': 21,
#    'end': 25}],
#  [{'entity': 'B-MISC',
#    'score': 0.9185363,
#    'index': 9,
#    'word': 'O',
#    'start': 27,
#    'end': 28},
#   {'entity': 'B-MISC',
#    'score': 0.44409588,
#    'index': 10,
#    'word': '##bi',
#    'start': 28,
#    'end': 30},
#   {'entity': 'I-MISC',
#    'score': 0.90192986,
#    'index': 11,
#    'word': '-',
#    'start': 30,
#    'end': 31},
#   {'entity': 'I-MISC',
#    'score': 0.5763373,
#    'index': 12,
#    'word': 'Wan',
#    'start': 31,
#    'end': 34},
#   {'entity': 'I-PER',
#    'score': 0.5401397,
#    'index': 13,
#    'word': 'Ken',
#    'start': 35,
#    'end': 38},
#   {'entity': 'I-PER',
#    'score': 0.57259023,
#    'index': 14,
#    'word': '##ob',
#    'start': 38,
#    'end': 40}],
#  [{'entity': 'B-ORG',
#    'score': 0.8319606,
#    'index': 7,
#    'word': 'Sand',
#    'start': 13,
#    'end': 17},
#   {'entity': 'I-ORG',
#    'score': 0.7905462,
#    'index': 8,
#    'word': 'People',
#    'start': 18,
#    'end': 24}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.7444245,
#    'index': 6,
#    'word': 'Ban',
#    'start': 22,
#    'end': 25},
#   {'entity': 'I-MISC',
#    'score': 0.79680187,
#    'index': 7,
#    'word': '##tha',
#    'start': 25,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.6984801,
#    'index': 3,
#    'word': 'Ben',
#    'start': 10,
#    'end': 13}],
#  [{'entity': 'B-PER',
#    'score': 0.98340684,
#    'index': 1,
#    'word': 'Ben',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.9931899,
#    'index': 2,
#    'word': 'Ken',
#    'start': 4,
#    'end': 7},
#   {'entity': 'I-PER',
#    'score': 0.96771497,
#    'index': 3,
#    'word': '##ob',
#    'start': 7,
#    'end': 9}],
#  [{'entity': 'B-MISC',
#    'score': 0.7324397,
#    'index': 3,
#    'word': 'Jun',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-MISC',
#    'score': 0.5218636,
#    'index': 4,
#    'word': '##dl',
#    'start': 11,
#    'end': 13},
#   {'entity': 'I-LOC',
#    'score': 0.5591968,
#    'index': 5,
#    'word': '##and',
#    'start': 13,
#    'end': 16},
#   {'entity': 'I-ORG',
#    'score': 0.36368474,
#    'index': 6,
#    'word': 'Waste',
#    'start': 17,
#    'end': 22}],
#  [{'entity': 'B-PER',
#    'score': 0.7434264,
#    'index': 3,
#    'word': 'Oh',
#    'start': 8,
#    'end': 10},
#   {'entity': 'B-PER',
#    'score': 0.84981847,
#    'index': 4,
#    'word': 'O',
#    'start': 11,
#    'end': 12},
#   {'entity': 'B-PER',
#    'score': 0.56931484,
#    'index': 5,
#    'word': '##bi',
#    'start': 12,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.6417413,
#    'index': 7,
#    'word': 'Wan',
#    'start': 15,
#    'end': 18},
#   {'entity': 'B-PER',
#    'score': 0.99524885,
#    'index': 14,
#    'word': 'O',
#    'start': 29,
#    'end': 30},
#   {'entity': 'B-PER',
#    'score': 0.53885233,
#    'index': 15,
#    'word': '##bi',
#    'start': 30,
#    'end': 32},
#   {'entity': 'I-PER',
#    'score': 0.53836864,
#    'index': 17,
#    'word': 'Wan',
#    'start': 33,
#    'end': 36}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.5253902,
#    'index': 2,
#    'word': 'Sand',
#    'start': 4,
#    'end': 8},
#   {'entity': 'I-MISC',
#    'score': 0.75499886,
#    'index': 3,
#    'word': 'People',
#    'start': 9,
#    'end': 15}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.61308944,
#    'index': 12,
#    'word': 'Sand',
#    'start': 40,
#    'end': 44},
#   {'entity': 'I-MISC',
#    'score': 0.83550584,
#    'index': 13,
#    'word': 'People',
#    'start': 45,
#    'end': 51}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9632447,
#    'index': 4,
#    'word': 'No',
#    'start': 10,
#    'end': 12},
#   {'entity': 'I-MISC',
#    'score': 0.9844395,
#    'index': 5,
#    'word': 'Quickly',
#    'start': 13,
#    'end': 20},
#   {'entity': 'I-MISC',
#    'score': 0.9981008,
#    'index': 6,
#    'word': 'No',
#    'start': 21,
#    'end': 23},
#   {'entity': 'I-MISC',
#    'score': 0.99658406,
#    'index': 7,
#    'word': 'That',
#    'start': 24,
#    'end': 28}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9990613,
#    'index': 5,
#    'word': 'C',
#    'start': 18,
#    'end': 19},
#   {'entity': 'I-MISC',
#    'score': 0.9628421,
#    'index': 6,
#    'word': '##lone',
#    'start': 19,
#    'end': 23},
#   {'entity': 'I-MISC',
#    'score': 0.99742424,
#    'index': 7,
#    'word': 'Wars',
#    'start': 24,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.98958987,
#    'index': 7,
#    'word': 'Jed',
#    'start': 24,
#    'end': 27},
#   {'entity': 'I-MISC',
#    'score': 0.98984295,
#    'index': 8,
#    'word': '##i',
#    'start': 27,
#    'end': 28},
#   {'entity': 'I-MISC',
#    'score': 0.9816304,
#    'index': 9,
#    'word': 'Knight',
#    'start': 29,
#    'end': 35}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.95627546,
#    'index': 7,
#    'word': 'Jed',
#    'start': 36,
#    'end': 39},
#   {'entity': 'I-MISC',
#    'score': 0.97228867,
#    'index': 8,
#    'word': '##i',
#    'start': 39,
#    'end': 40},
#   {'entity': 'I-MISC',
#    'score': 0.91934955,
#    'index': 9,
#    'word': 'Knights',
#    'start': 41,
#    'end': 48},
#   {'entity': 'B-LOC',
#    'score': 0.95202,
#    'index': 20,
#    'word': 'Old',
#    'start': 96,
#    'end': 99},
#   {'entity': 'I-LOC',
#    'score': 0.9887679,
#    'index': 21,
#    'word': 'Republic',
#    'start': 100,
#    'end': 108}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9937495,
#    'index': 3,
#    'word': 'Jed',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-MISC',
#    'score': 0.96640545,
#    'index': 4,
#    'word': '##i',
#    'start': 11,
#    'end': 12},
#   {'entity': 'B-PER',
#    'score': 0.7352909,
#    'index': 6,
#    'word': 'Dar',
#    'start': 19,
#    'end': 22},
#   {'entity': 'I-MISC',
#    'score': 0.5342446,
#    'index': 7,
#    'word': '##th',
#    'start': 22,
#    'end': 24},
#   {'entity': 'I-PER',
#    'score': 0.90167695,
#    'index': 8,
#    'word': 'V',
#    'start': 25,
#    'end': 26},
#   {'entity': 'I-PER',
#    'score': 0.735046,
#    'index': 9,
#    'word': '##ader',
#    'start': 26,
#    'end': 30},
#   {'entity': 'I-MISC',
#    'score': 0.4119632,
#    'index': 11,
#    'word': 'Force',
#    'start': 35,
#    'end': 40}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9886867,
#    'index': 2,
#    'word': 'Ken',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-PER',
#    'score': 0.61519575,
#    'index': 3,
#    'word': '##ob',
#    'start': 11,
#    'end': 13},
#   {'entity': 'B-ORG',
#    'score': 0.95552474,
#    'index': 12,
#    'word': 'Force',
#    'start': 46,
#    'end': 51},
#   {'entity': 'B-LOC',
#    'score': 0.9990546,
#    'index': 22,
#    'word': 'Al',
#    'start': 81,
#    'end': 83},
#   {'entity': 'I-LOC',
#    'score': 0.9889075,
#    'index': 23,
#    'word': '##der',
#    'start': 83,
#    'end': 86},
#   {'entity': 'I-LOC',
#    'score': 0.9974437,
#    'index': 24,
#    'word': '##aan',
#    'start': 86,
#    'end': 89}],
#  [{'entity': 'B-LOC',
#    'score': 0.95441204,
#    'index': 1,
#    'word': 'Al',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-LOC',
#    'score': 0.93326867,
#    'index': 2,
#    'word': '##der',
#    'start': 2,
#    'end': 5},
#   {'entity': 'I-LOC',
#    'score': 0.97006744,
#    'index': 3,
#    'word': '##aan',
#    'start': 5,
#    'end': 8}],
#  [{'entity': 'B-LOC',
#    'score': 0.9975253,
#    'index': 7,
#    'word': 'Al',
#    'start': 17,
#    'end': 19},
#   {'entity': 'I-LOC',
#    'score': 0.9902564,
#    'index': 8,
#    'word': '##der',
#    'start': 19,
#    'end': 22},
#   {'entity': 'I-LOC',
#    'score': 0.99423224,
#    'index': 9,
#    'word': '##aan',
#    'start': 22,
#    'end': 25}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.8185533,
#    'index': 9,
#    'word': 'Empire',
#    'start': 25,
#    'end': 31}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.6770168,
#    'index': 6,
#    'word': 'Force',
#    'start': 19,
#    'end': 24}],
#  [{'entity': 'B-ORG',
#    'score': 0.99787474,
#    'index': 2,
#    'word': 'Rebel',
#    'start': 4,
#    'end': 9},
#   {'entity': 'I-ORG',
#    'score': 0.9974474,
#    'index': 3,
#    'word': 'Alliance',
#    'start': 10,
#    'end': 18}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.6240213,
#    'index': 8,
#    'word': 'Rebellion',
#    'start': 32,
#    'end': 41},
#   {'entity': 'B-ORG',
#    'score': 0.9283743,
#    'index': 16,
#    'word': 'Imperial',
#    'start': 79,
#    'end': 87},
#   {'entity': 'B-ORG',
#    'score': 0.71272045,
#    'index': 17,
#    'word': 'Senate',
#    'start': 88,
#    'end': 94}],
#  [{'entity': 'B-ORG',
#    'score': 0.74853206,
#    'index': 2,
#    'word': 'Imperial',
#    'start': 4,
#    'end': 12},
#   {'entity': 'B-ORG',
#    'score': 0.9445802,
#    'index': 3,
#    'word': 'Senate',
#    'start': 13,
#    'end': 19}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.8306972,
#    'index': 6,
#    'word': 'Old',
#    'start': 25,
#    'end': 28},
#   {'entity': 'I-LOC',
#    'score': 0.8171838,
#    'index': 7,
#    'word': 'Republic',
#    'start': 29,
#    'end': 37}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.91759646,
#    'index': 5,
#    'word': 'Rebellion',
#    'start': 16,
#    'end': 25}],
#  [{'entity': 'B-ORG',
#    'score': 0.65885854,
#    'index': 3,
#    'word': 'Rebels',
#    'start': 7,
#    'end': 13}],
#  [{'entity': 'B-MISC',
#    'score': 0.8518934,
#    'index': 6,
#    'word': 'Rebels',
#    'start': 23,
#    'end': 29}],
#  [{'entity': 'B-ORG',
#    'score': 0.7965668,
#    'index': 17,
#    'word': 'Force',
#    'start': 74,
#    'end': 79}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.68483967,
#    'index': 1,
#    'word': 'V',
#    'start': 0,
#    'end': 1},
#   {'entity': 'I-PER',
#    'score': 0.5906603,
#    'index': 2,
#    'word': '##ader',
#    'start': 1,
#    'end': 5}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.97090244,
#    'index': 2,
#    'word': 'V',
#    'start': 5,
#    'end': 6},
#   {'entity': 'I-PER',
#    'score': 0.79484135,
#    'index': 3,
#    'word': '##ader',
#    'start': 6,
#    'end': 10},
#   {'entity': 'B-MISC',
#    'score': 0.9990695,
#    'index': 12,
#    'word': 'Rebel',
#    'start': 52,
#    'end': 57}],
#  [{'entity': 'B-MISC',
#    'score': 0.50600106,
#    'index': 6,
#    'word': 'Rebellion',
#    'start': 23,
#    'end': 32}],
#  [{'entity': 'B-ORG',
#    'score': 0.92489713,
#    'index': 4,
#    'word': 'Sand',
#    'start': 14,
#    'end': 18},
#   {'entity': 'I-ORG',
#    'score': 0.93516773,
#    'index': 5,
#    'word': 'People',
#    'start': 19,
#    'end': 25}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9351226,
#    'index': 5,
#    'word': 'J',
#    'start': 19,
#    'end': 20},
#   {'entity': 'B-ORG',
#    'score': 0.8749611,
#    'index': 11,
#    'word': 'Art',
#    'start': 38,
#    'end': 41},
#   {'entity': 'I-MISC',
#    'score': 0.69839966,
#    'index': 12,
#    'word': '##oo',
#    'start': 41,
#    'end': 43},
#   {'entity': 'B-ORG',
#    'score': 0.5403564,
#    'index': 14,
#    'word': 'Three',
#    'start': 48,
#    'end': 53},
#   {'entity': 'I-MISC',
#    'score': 0.6911637,
#    'index': 15,
#    'word': '##pio',
#    'start': 53,
#    'end': 56}],
#  [{'entity': 'B-MISC',
#    'score': 0.8856042,
#    'index': 7,
#    'word': 'Imperial',
#    'start': 33,
#    'end': 41},
#   {'entity': 'B-PER',
#    'score': 0.79326653,
#    'index': 12,
#    'word': 'J',
#    'start': 67,
#    'end': 68}],
#  [{'entity': 'B-PER',
#    'score': 0.6482033,
#    'index': 9,
#    'word': 'Owen',
#    'start': 42,
#    'end': 46}],
#  [{'entity': 'B-PER',
#    'score': 0.50651735,
#    'index': 1,
#    'word': 'Aunt',
#    'start': 0,
#    'end': 4},
#   {'entity': 'I-PER',
#    'score': 0.6101835,
#    'index': 2,
#    'word': 'Be',
#    'start': 5,
#    'end': 7}],
#  [{'entity': 'B-PER',
#    'score': 0.9515605,
#    'index': 2,
#    'word': 'Owen',
#    'start': 6,
#    'end': 10}],
#  [{'entity': 'B-LOC',
#    'score': 0.9979042,
#    'index': 17,
#    'word': 'Al',
#    'start': 67,
#    'end': 69},
#   {'entity': 'I-LOC',
#    'score': 0.9889332,
#    'index': 18,
#    'word': '##der',
#    'start': 69,
#    'end': 72},
#   {'entity': 'I-LOC',
#    'score': 0.9955741,
#    'index': 19,
#    'word': '##aan',
#    'start': 72,
#    'end': 75}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.91320956,
#    'index': 9,
#    'word': 'Force',
#    'start': 32,
#    'end': 37},
#   {'entity': 'B-MISC',
#    'score': 0.81145865,
#    'index': 13,
#    'word': 'Jed',
#    'start': 51,
#    'end': 54},
#   {'entity': 'I-MISC',
#    'score': 0.9159184,
#    'index': 14,
#    'word': '##i',
#    'start': 54,
#    'end': 55}],
#  [{'entity': 'B-ORG',
#    'score': 0.99892527,
#    'index': 1,
#    'word': 'Mo',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-ORG',
#    'score': 0.9899575,
#    'index': 2,
#    'word': '##s',
#    'start': 2,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.99910384,
#    'index': 3,
#    'word': 'E',
#    'start': 4,
#    'end': 5},
#   {'entity': 'I-ORG',
#    'score': 0.9967334,
#    'index': 4,
#    'word': '##is',
#    'start': 5,
#    'end': 7},
#   {'entity': 'I-ORG',
#    'score': 0.99835783,
#    'index': 5,
#    'word': '##ley',
#    'start': 7,
#    'end': 10},
#   {'entity': 'I-ORG',
#    'score': 0.99919444,
#    'index': 6,
#    'word': 'Space',
#    'start': 11,
#    'end': 16},
#   {'entity': 'I-ORG',
#    'score': 0.9985299,
#    'index': 7,
#    'word': '##port',
#    'start': 16,
#    'end': 20}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.8869287,
#    'index': 8,
#    'word': 'J',
#    'start': 20,
#    'end': 21}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9044677,
#    'index': 3,
#    'word': 'The',
#    'start': 6,
#    'end': 9},
#   {'entity': 'I-ORG',
#    'score': 0.9572648,
#    'index': 4,
#    'word': 'Force',
#    'start': 10,
#    'end': 15}],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9992986,
#    'index': 20,
#    'word': 'Al',
#    'start': 72,
#    'end': 74},
#   {'entity': 'I-LOC',
#    'score': 0.9836464,
#    'index': 21,
#    'word': '##der',
#    'start': 74,
#    'end': 77},
#   {'entity': 'I-LOC',
#    'score': 0.9967199,
#    'index': 22,
#    'word': '##aan',
#    'start': 77,
#    'end': 80}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9863253,
#    'index': 3,
#    'word': 'Ch',
#    'start': 8,
#    'end': 10},
#   {'entity': 'B-ORG',
#    'score': 0.71456283,
#    'index': 4,
#    'word': '##ew',
#    'start': 10,
#    'end': 12},
#   {'entity': 'I-ORG',
#    'score': 0.98322415,
#    'index': 5,
#    'word': '##ba',
#    'start': 12,
#    'end': 14},
#   {'entity': 'I-ORG',
#    'score': 0.92938316,
#    'index': 6,
#    'word': '##cca',
#    'start': 14,
#    'end': 17}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9929576,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.99668473,
#    'index': 2,
#    'word': 'Solo',
#    'start': 4,
#    'end': 8}],
#  [{'entity': 'B-MISC',
#    'score': 0.86915743,
#    'index': 7,
#    'word': 'Millennium',
#    'start': 19,
#    'end': 29},
#   {'entity': 'I-MISC',
#    'score': 0.7494157,
#    'index': 8,
#    'word': 'Falcon',
#    'start': 30,
#    'end': 36}],
#  [{'entity': 'B-PER',
#    'score': 0.9904426,
#    'index': 1,
#    'word': 'Ch',
#    'start': 0,
#    'end': 2},
#   {'entity': 'B-PER',
#    'score': 0.9785122,
#    'index': 2,
#    'word': '##ew',
#    'start': 2,
#    'end': 4},
#   {'entity': 'B-LOC',
#    'score': 0.93447256,
#    'index': 15,
#    'word': 'Al',
#    'start': 55,
#    'end': 57},
#   {'entity': 'I-LOC',
#    'score': 0.9497503,
#    'index': 16,
#    'word': '##der',
#    'start': 57,
#    'end': 60},
#   {'entity': 'I-LOC',
#    'score': 0.93448275,
#    'index': 17,
#    'word': '##aan',
#    'start': 60,
#    'end': 63}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.99635065,
#    'index': 8,
#    'word': 'Millennium',
#    'start': 26,
#    'end': 36},
#   {'entity': 'I-MISC',
#    'score': 0.99573565,
#    'index': 9,
#    'word': 'Falcon',
#    'start': 37,
#    'end': 43}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.99433607,
#    'index': 9,
#    'word': 'Ke',
#    'start': 28,
#    'end': 30},
#   {'entity': 'I-MISC',
#    'score': 0.8934136,
#    'index': 10,
#    'word': '##ssel',
#    'start': 30,
#    'end': 34}],
#  [{'entity': 'B-MISC',
#    'score': 0.7974171,
#    'index': 6,
#    'word': 'Imperial',
#    'start': 12,
#    'end': 20}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.97801447,
#    'index': 13,
#    'word': 'Imperial',
#    'start': 38,
#    'end': 46}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.98031986,
#    'index': 1,
#    'word': 'J',
#    'start': 0,
#    'end': 1},
#   {'entity': 'B-PER',
#    'score': 0.45107827,
#    'index': 2,
#    'word': '##ab',
#    'start': 1,
#    'end': 3},
#   {'entity': 'B-PER',
#    'score': 0.56319237,
#    'index': 3,
#    'word': '##ba',
#    'start': 3,
#    'end': 5}],
#  [{'entity': 'B-PER',
#    'score': 0.98268986,
#    'index': 2,
#    'word': 'J',
#    'start': 5,
#    'end': 6},
#   {'entity': 'B-PER',
#    'score': 0.9950753,
#    'index': 8,
#    'word': 'J',
#    'start': 15,
#    'end': 16},
#   {'entity': 'B-PER',
#    'score': 0.3059702,
#    'index': 9,
#    'word': '##ab',
#    'start': 16,
#    'end': 18},
#   {'entity': 'B-PER',
#    'score': 0.67529494,
#    'index': 10,
#    'word': '##ba',
#    'start': 18,
#    'end': 20}],
#  [{'entity': 'B-MISC',
#    'score': 0.94356555,
#    'index': 20,
#    'word': 'Imperial',
#    'start': 78,
#    'end': 86}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99821126,
#    'index': 6,
#    'word': 'J',
#    'start': 21,
#    'end': 22},
#   {'entity': 'B-PER',
#    'score': 0.5630487,
#    'index': 7,
#    'word': '##ab',
#    'start': 22,
#    'end': 24},
#   {'entity': 'B-PER',
#    'score': 0.7858065,
#    'index': 8,
#    'word': '##ba',
#    'start': 24,
#    'end': 26}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.7195144,
#    'index': 20,
#    'word': 'Le',
#    'start': 94,
#    'end': 96},
#   {'entity': 'B-LOC',
#    'score': 0.99877197,
#    'index': 27,
#    'word': 'Al',
#    'start': 116,
#    'end': 118},
#   {'entity': 'I-LOC',
#    'score': 0.97910404,
#    'index': 28,
#    'word': '##der',
#    'start': 118,
#    'end': 121},
#   {'entity': 'I-LOC',
#    'score': 0.9966158,
#    'index': 29,
#    'word': '##aan',
#    'start': 121,
#    'end': 124}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.47368687,
#    'index': 13,
#    'word': 'Master',
#    'start': 59,
#    'end': 65},
#   {'entity': 'I-PER',
#    'score': 0.67366725,
#    'index': 14,
#    'word': 'Luke',
#    'start': 66,
#    'end': 70}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9980052,
#    'index': 3,
#    'word': 'X',
#    'start': 10,
#    'end': 11},
#   {'entity': 'I-MISC',
#    'score': 0.9942246,
#    'index': 4,
#    'word': '##P',
#    'start': 11,
#    'end': 12},
#   {'entity': 'I-MISC',
#    'score': 0.98215127,
#    'index': 5,
#    'word': '-',
#    'start': 12,
#    'end': 13},
#   {'entity': 'I-MISC',
#    'score': 0.996073,
#    'index': 6,
#    'word': '38',
#    'start': 13,
#    'end': 15}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99475104,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.99520975,
#    'index': 2,
#    'word': 'You',
#    'start': 4,
#    'end': 7},
#   {'entity': 'B-PER',
#    'score': 0.99948907,
#    'index': 4,
#    'word': 'G',
#    'start': 13,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.9243244,
#    'index': 5,
#    'word': '##reed',
#    'start': 14,
#    'end': 18}],
#  [{'entity': 'B-PER',
#    'score': 0.99615806,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.93490636,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.9193919,
#    'index': 2,
#    'word': 'J',
#    'start': 4,
#    'end': 5},
#   {'entity': 'I-PER',
#    'score': 0.5814138,
#    'index': 3,
#    'word': '##ab',
#    'start': 5,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.48343882,
#    'index': 2,
#    'word': '##ew',
#    'start': 2,
#    'end': 4},
#   {'entity': 'B-MISC',
#    'score': 0.97883683,
#    'index': 9,
#    'word': 'Imperial',
#    'start': 27,
#    'end': 35}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.94842684,
#    'index': 10,
#    'word': 'Al',
#    'start': 39,
#    'end': 41},
#   {'entity': 'I-LOC',
#    'score': 0.5772003,
#    'index': 11,
#    'word': '##der',
#    'start': 41,
#    'end': 44},
#   {'entity': 'I-MISC',
#    'score': 0.85842043,
#    'index': 12,
#    'word': '##aan',
#    'start': 44,
#    'end': 47}],
#  [{'entity': 'B-PER',
#    'score': 0.9994404,
#    'index': 2,
#    'word': 'Ta',
#    'start': 9,
#    'end': 11},
#   {'entity': 'B-PER',
#    'score': 0.84929895,
#    'index': 3,
#    'word': '##rkin',
#    'start': 11,
#    'end': 15},
#   {'entity': 'I-PER',
#    'score': 0.9975479,
#    'index': 4,
#    'word': 'Cha',
#    'start': 16,
#    'end': 19},
#   {'entity': 'I-PER',
#    'score': 0.9942141,
#    'index': 5,
#    'word': '##rming',
#    'start': 19,
#    'end': 24}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.924701,
#    'index': 2,
#    'word': 'Le',
#    'start': 9,
#    'end': 11}],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.99069524,
#    'index': 1,
#    'word': 'Al',
#    'start': 0,
#    'end': 2},
#   {'entity': 'I-LOC',
#    'score': 0.9281708,
#    'index': 2,
#    'word': '##der',
#    'start': 2,
#    'end': 5},
#   {'entity': 'I-LOC',
#    'score': 0.9925661,
#    'index': 3,
#    'word': '##aan',
#    'start': 5,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.99880826,
#    'index': 4,
#    'word': 'Rebel',
#    'start': 13,
#    'end': 18}],
#  [{'entity': 'B-PER',
#    'score': 0.9955753,
#    'index': 1,
#    'word': 'Dan',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.6545372,
#    'index': 2,
#    'word': '##to',
#    'start': 3,
#    'end': 5},
#   {'entity': 'B-PER',
#    'score': 0.40033,
#    'index': 3,
#    'word': '##oi',
#    'start': 5,
#    'end': 7},
#   {'entity': 'B-PER',
#    'score': 0.717253,
#    'index': 4,
#    'word': '##ne',
#    'start': 7,
#    'end': 9}],
#  [{'entity': 'B-PER',
#    'score': 0.96293163,
#    'index': 5,
#    'word': 'Dan',
#    'start': 11,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.36702392,
#    'index': 6,
#    'word': '##to',
#    'start': 14,
#    'end': 16}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.59006196,
#    'index': 3,
#    'word': 'Lord',
#    'start': 8,
#    'end': 12},
#   {'entity': 'B-PER',
#    'score': 0.9435215,
#    'index': 4,
#    'word': 'V',
#    'start': 13,
#    'end': 14},
#   {'entity': 'I-PER',
#    'score': 0.83124644,
#    'index': 5,
#    'word': '##ader',
#    'start': 14,
#    'end': 18}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99623126,
#    'index': 1,
#    'word': 'Dan',
#    'start': 0,
#    'end': 3},
#   {'entity': 'B-PER',
#    'score': 0.54422456,
#    'index': 2,
#    'word': '##to',
#    'start': 3,
#    'end': 5},
#   {'entity': 'B-PER',
#    'score': 0.4544366,
#    'index': 3,
#    'word': '##oi',
#    'start': 5,
#    'end': 7},
#   {'entity': 'B-PER',
#    'score': 0.67358965,
#    'index': 4,
#    'word': '##ne',
#    'start': 7,
#    'end': 9}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9978048,
#    'index': 6,
#    'word': 'Rebel',
#    'start': 23,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.89986074,
#    'index': 8,
#    'word': 'Force',
#    'start': 34,
#    'end': 39}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9167993,
#    'index': 9,
#    'word': 'W',
#    'start': 25,
#    'end': 26}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.97362363,
#    'index': 25,
#    'word': 'Force',
#    'start': 106,
#    'end': 111},
#   {'entity': 'I-MISC',
#    'score': 0.9946997,
#    'index': 26,
#    'word': 'Kid',
#    'start': 112,
#    'end': 115}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.97312635,
#    'index': 13,
#    'word': 'Al',
#    'start': 52,
#    'end': 54},
#   {'entity': 'I-LOC',
#    'score': 0.9605702,
#    'index': 14,
#    'word': '##der',
#    'start': 54,
#    'end': 57},
#   {'entity': 'I-LOC',
#    'score': 0.9236947,
#    'index': 15,
#    'word': '##aan',
#    'start': 57,
#    'end': 60}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.48092288,
#    'index': 6,
#    'word': 'Dan',
#    'start': 29,
#    'end': 32},
#   {'entity': 'I-LOC',
#    'score': 0.5017345,
#    'index': 7,
#    'word': '##to',
#    'start': 32,
#    'end': 34}],
#  [{'entity': 'B-MISC',
#    'score': 0.9986547,
#    'index': 7,
#    'word': 'Rebel',
#    'start': 28,
#    'end': 33}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.4360029,
#    'index': 10,
#    'word': 'Rebellion',
#    'start': 50,
#    'end': 59}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.43187514,
#    'index': 9,
#    'word': 'Empire',
#    'start': 20,
#    'end': 26}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.9976603,
#    'index': 5,
#    'word': 'Imperial',
#    'start': 8,
#    'end': 16}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9533547,
#    'index': 1,
#    'word': 'Clear',
#    'start': 0,
#    'end': 5},
#   {'entity': 'I-LOC',
#    'score': 0.99148154,
#    'index': 2,
#    'word': 'Bay',
#    'start': 6,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9863344,
#    'index': 13,
#    'word': 'Al',
#    'start': 55,
#    'end': 57},
#   {'entity': 'I-LOC',
#    'score': 0.97325474,
#    'index': 14,
#    'word': '##der',
#    'start': 57,
#    'end': 60},
#   {'entity': 'I-LOC',
#    'score': 0.98359126,
#    'index': 15,
#    'word': '##aan',
#    'start': 60,
#    'end': 63}],
#  [{'entity': 'B-LOC',
#    'score': 0.9624017,
#    'index': 16,
#    'word': 'Mo',
#    'start': 64,
#    'end': 66},
#   {'entity': 'I-LOC',
#    'score': 0.9535693,
#    'index': 17,
#    'word': '##s',
#    'start': 66,
#    'end': 67},
#   {'entity': 'I-LOC',
#    'score': 0.9821488,
#    'index': 18,
#    'word': 'E',
#    'start': 68,
#    'end': 69},
#   {'entity': 'I-LOC',
#    'score': 0.9535138,
#    'index': 19,
#    'word': '##is',
#    'start': 69,
#    'end': 71},
#   {'entity': 'I-LOC',
#    'score': 0.9789449,
#    'index': 20,
#    'word': '##ley',
#    'start': 71,
#    'end': 74}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9980621,
#    'index': 1,
#    'word': 'TX',
#    'start': 0,
#    'end': 2}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.940578,
#    'index': 6,
#    'word': 'P',
#    'start': 29,
#    'end': 30}],
#  [{'entity': 'B-ORG',
#    'score': 0.74329144,
#    'index': 9,
#    'word': 'Imperial',
#    'start': 42,
#    'end': 50}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-LOC',
#    'score': 0.9515851,
#    'index': 16,
#    'word': 'Al',
#    'start': 81,
#    'end': 83},
#   {'entity': 'I-LOC',
#    'score': 0.8914392,
#    'index': 17,
#    'word': '##der',
#    'start': 83,
#    'end': 86},
#   {'entity': 'I-LOC',
#    'score': 0.8922202,
#    'index': 18,
#    'word': '##aan',
#    'start': 86,
#    'end': 89}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6179301,
#    'index': 2,
#    'word': 'Force',
#    'start': 4,
#    'end': 9}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9989297,
#    'index': 1,
#    'word': 'Ben',
#    'start': 0,
#    'end': 3}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.94310045,
#    'index': 13,
#    'word': 'Le',
#    'start': 44,
#    'end': 46}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.72769827,
#    'index': 1,
#    'word': 'Han',
#    'start': 0,
#    'end': 3},
#   {'entity': 'B-PER',
#    'score': 0.510313,
#    'index': 7,
#    'word': 'Luke',
#    'start': 23,
#    'end': 27}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.48499668,
#    'index': 5,
#    'word': 'Block',
#    'start': 23,
#    'end': 28}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.86218286,
#    'index': 6,
#    'word': 'Luke',
#    'start': 27,
#    'end': 31}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9965228,
#    'index': 4,
#    'word': 'Luke',
#    'start': 4,
#    'end': 8},
#   {'entity': 'I-PER',
#    'score': 0.9973871,
#    'index': 5,
#    'word': 'Sky',
#    'start': 9,
#    'end': 12},
#   {'entity': 'I-PER',
#    'score': 0.99278814,
#    'index': 6,
#    'word': '##walk',
#    'start': 12,
#    'end': 16},
#   {'entity': 'I-PER',
#    'score': 0.87892216,
#    'index': 7,
#    'word': '##er',
#    'start': 16,
#    'end': 18}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9991266,
#    'index': 6,
#    'word': 'Ben',
#    'start': 14,
#    'end': 17},
#   {'entity': 'I-PER',
#    'score': 0.9993199,
#    'index': 7,
#    'word': 'Ken',
#    'start': 18,
#    'end': 21},
#   {'entity': 'I-PER',
#    'score': 0.9929391,
#    'index': 8,
#    'word': '##ob',
#    'start': 21,
#    'end': 23}],
#  [{'entity': 'B-PER',
#    'score': 0.99946004,
#    'index': 1,
#    'word': 'Ben',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.9995271,
#    'index': 2,
#    'word': 'Ken',
#    'start': 4,
#    'end': 7},
#   {'entity': 'I-PER',
#    'score': 0.9982192,
#    'index': 3,
#    'word': '##ob',
#    'start': 7,
#    'end': 9}],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9984907,
#    'index': 7,
#    'word': 'O',
#    'start': 15,
#    'end': 16},
#   {'entity': 'B-PER',
#    'score': 0.9860669,
#    'index': 8,
#    'word': '##bi',
#    'start': 16,
#    'end': 18},
#   {'entity': 'I-PER',
#    'score': 0.83055097,
#    'index': 10,
#    'word': 'Wan',
#    'start': 19,
#    'end': 22},
#   {'entity': 'I-PER',
#    'score': 0.72751284,
#    'index': 11,
#    'word': 'Ken',
#    'start': 23,
#    'end': 26},
#   {'entity': 'I-PER',
#    'score': 0.7741835,
#    'index': 12,
#    'word': '##ob',
#    'start': 26,
#    'end': 28}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.89171946,
#    'index': 7,
#    'word': 'Force',
#    'start': 16,
#    'end': 21}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.60365665,
#    'index': 8,
#    'word': 'Force',
#    'start': 24,
#    'end': 29}],
#  [{'entity': 'B-MISC',
#    'score': 0.99429977,
#    'index': 2,
#    'word': 'Jed',
#    'start': 4,
#    'end': 7},
#   {'entity': 'I-MISC',
#    'score': 0.96935105,
#    'index': 3,
#    'word': '##i',
#    'start': 7,
#    'end': 8}],
#  [{'entity': 'B-PER',
#    'score': 0.99882036,
#    'index': 2,
#    'word': 'Ta',
#    'start': 9,
#    'end': 11},
#   {'entity': 'I-PER',
#    'score': 0.49213094,
#    'index': 3,
#    'word': '##rkin',
#    'start': 11,
#    'end': 15}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99745435,
#    'index': 1,
#    'word': 'O',
#    'start': 0,
#    'end': 1},
#   {'entity': 'B-PER',
#    'score': 0.94708824,
#    'index': 2,
#    'word': '##bi',
#    'start': 1,
#    'end': 3},
#   {'entity': 'I-PER',
#    'score': 0.4047475,
#    'index': 3,
#    'word': '-',
#    'start': 3,
#    'end': 4},
#   {'entity': 'I-PER',
#    'score': 0.7247256,
#    'index': 4,
#    'word': 'Wan',
#    'start': 4,
#    'end': 7}],
#  [{'entity': 'B-ORG',
#    'score': 0.9135823,
#    'index': 2,
#    'word': 'Force',
#    'start': 4,
#    'end': 9}],
#  [{'entity': 'B-PER',
#    'score': 0.83325773,
#    'index': 6,
#    'word': 'Escape',
#    'start': 16,
#    'end': 22}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.6695648,
#    'index': 11,
#    'word': 'See',
#    'start': 38,
#    'end': 41},
#   {'entity': 'I-MISC',
#    'score': 0.6850041,
#    'index': 13,
#    'word': 'Three',
#    'start': 42,
#    'end': 47}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.7465535,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.7465535,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.7465535,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.7465535,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.7465535,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-PER',
#    'score': 0.7465535,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.30012965,
#    'index': 3,
#    'word': 'Three',
#    'start': 8,
#    'end': 13}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.36492074,
#    'index': 5,
#    'word': 'Three',
#    'start': 17,
#    'end': 22}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.7566021,
#    'index': 4,
#    'word': 'Ch',
#    'start': 13,
#    'end': 15}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.32278508,
#    'index': 3,
#    'word': 'Three',
#    'start': 4,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.88953954,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.4846735,
#    'index': 9,
#    'word': 'Art',
#    'start': 42,
#    'end': 45},
#   {'entity': 'I-MISC',
#    'score': 0.8738919,
#    'index': 10,
#    'word': '##oo',
#    'start': 45,
#    'end': 47}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.8522392,
#    'index': 5,
#    'word': 'Al',
#    'start': 20,
#    'end': 22},
#   {'entity': 'I-PER',
#    'score': 0.413643,
#    'index': 6,
#    'word': '##der',
#    'start': 22,
#    'end': 25},
#   {'entity': 'I-MISC',
#    'score': 0.63843006,
#    'index': 7,
#    'word': '##aan',
#    'start': 25,
#    'end': 28}],
#  [{'entity': 'B-LOC',
#    'score': 0.8313433,
#    'index': 6,
#    'word': 'Ya',
#    'start': 30,
#    'end': 32},
#   {'entity': 'I-LOC',
#    'score': 0.6983122,
#    'index': 7,
#    'word': '##vin',
#    'start': 32,
#    'end': 35}],
#  [{'entity': 'B-MISC',
#    'score': 0.99864393,
#    'index': 2,
#    'word': 'Rebel',
#    'start': 4,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.7865725,
#    'index': 13,
#    'word': 'T',
#    'start': 35,
#    'end': 36}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.6677924,
#    'index': 4,
#    'word': 'Force',
#    'start': 12,
#    'end': 17}],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.99896526,
#    'index': 5,
#    'word': 'Rebel',
#    'start': 18,
#    'end': 23}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.59372187,
#    'index': 7,
#    'word': 'Ken',
#    'start': 23,
#    'end': 26},
#   {'entity': 'I-MISC',
#    'score': 0.29810598,
#    'index': 8,
#    'word': '##ob',
#    'start': 26,
#    'end': 28},
#   {'entity': 'B-MISC',
#    'score': 0.81227267,
#    'index': 19,
#    'word': 'Rebellion',
#    'start': 66,
#    'end': 75}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.99479127,
#    'index': 4,
#    'word': 'Ben',
#    'start': 12,
#    'end': 15}],
#  [{'entity': 'B-PER',
#    'score': 0.7465535,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.9951408,
#    'index': 8,
#    'word': 'Luke',
#    'start': 21,
#    'end': 25},
#   {'entity': 'I-PER',
#    'score': 0.99280834,
#    'index': 9,
#    'word': 'Sky',
#    'start': 26,
#    'end': 29},
#   {'entity': 'I-PER',
#    'score': 0.9794983,
#    'index': 10,
#    'word': '##walk',
#    'start': 29,
#    'end': 33}],
#  [{'entity': 'B-ORG',
#    'score': 0.65013754,
#    'index': 8,
#    'word': 'Inc',
#    'start': 33,
#    'end': 36},
#   {'entity': 'I-MISC',
#    'score': 0.76448506,
#    'index': 9,
#    'word': '##om',
#    'start': 36,
#    'end': 38},
#   {'entity': 'I-MISC',
#    'score': 0.73005253,
#    'index': 10,
#    'word': 'T',
#    'start': 39,
#    'end': 40}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.7408534,
#    'index': 30,
#    'word': 'Luke',
#    'start': 125,
#    'end': 129}],
#  [{'entity': 'B-ORG',
#    'score': 0.997209,
#    'index': 1,
#    'word': 'Death',
#    'start': 0,
#    'end': 5},
#   {'entity': 'I-ORG',
#    'score': 0.9936034,
#    'index': 2,
#    'word': 'Star',
#    'start': 6,
#    'end': 10}],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9919159,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.9888325,
#    'index': 2,
#    'word': 'Ten',
#    'start': 4,
#    'end': 7}],
#  [{'entity': 'B-ORG',
#    'score': 0.9101146,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.81034553,
#    'index': 2,
#    'word': 'Seven',
#    'start': 4,
#    'end': 9}],
#  [{'entity': 'B-ORG',
#    'score': 0.93420947,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.86942303,
#    'index': 2,
#    'word': 'Three',
#    'start': 4,
#    'end': 9}],
#  [{'entity': 'B-ORG',
#    'score': 0.9260603,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.90149194,
#    'index': 2,
#    'word': 'Six',
#    'start': 4,
#    'end': 7}],
#  [{'entity': 'B-ORG',
#    'score': 0.98875356,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.97291,
#    'index': 2,
#    'word': 'Nine',
#    'start': 4,
#    'end': 8}],
#  [{'entity': 'B-ORG',
#    'score': 0.8483496,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.7977975,
#    'index': 2,
#    'word': 'Two',
#    'start': 4,
#    'end': 7}],
#  [{'entity': 'B-ORG',
#    'score': 0.9995832,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.99763465,
#    'index': 2,
#    'word': 'Eleven',
#    'start': 4,
#    'end': 10}],
#  [{'entity': 'B-ORG',
#    'score': 0.8500483,
#    'index': 1,
#    'word': 'Red',
#    'start': 0,
#    'end': 3},
#   {'entity': 'I-ORG',
#    'score': 0.8585835,
#    'index': 2,
#    'word': 'Five',
#    'start': 4,
#    'end': 8}],
#  [{'entity': 'I-MISC',
#    'score': 0.48101902,
#    'index': 2,
#    'word': 'S',
#    'start': 5,
#    'end': 6}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.86401343,
#    'index': 4,
#    'word': 'Red',
#    'start': 11,
#    'end': 14},
#   {'entity': 'I-ORG',
#    'score': 0.88196445,
#    'index': 5,
#    'word': 'Leader',
#    'start': 15,
#    'end': 21}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.8845809,
#    'index': 3,
#    'word': 'Red',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-MISC',
#    'score': 0.89903605,
#    'index': 4,
#    'word': 'Five',
#    'start': 12,
#    'end': 16}],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.997517,
#    'index': 9,
#    'word': 'Rebel',
#    'start': 38,
#    'end': 43}],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.8823991,
#    'index': 1,
#    'word': 'Luke',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.63124,
#    'index': 6,
#    'word': 'Big',
#    'start': 22,
#    'end': 25},
#   {'entity': 'I-MISC',
#    'score': 0.38873327,
#    'index': 7,
#    'word': '##gs',
#    'start': 25,
#    'end': 27}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-MISC',
#    'score': 0.8288226,
#    'index': 10,
#    'word': 'Art',
#    'start': 28,
#    'end': 31},
#   {'entity': 'I-MISC',
#    'score': 0.9249303,
#    'index': 11,
#    'word': '##oo',
#    'start': 31,
#    'end': 33},
#   {'entity': 'I-MISC',
#    'score': 0.966093,
#    'index': 12,
#    'word': 'Red',
#    'start': 34,
#    'end': 37},
#   {'entity': 'I-MISC',
#    'score': 0.9552146,
#    'index': 13,
#    'word': 'Six',
#    'start': 38,
#    'end': 41},
#   {'entity': 'B-MISC',
#    'score': 0.9190756,
#    'index': 20,
#    'word': 'Red',
#    'start': 58,
#    'end': 61},
#   {'entity': 'I-MISC',
#    'score': 0.9717571,
#    'index': 21,
#    'word': 'Five',
#    'start': 62,
#    'end': 66}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.993985,
#    'index': 5,
#    'word': 'Death',
#    'start': 20,
#    'end': 25},
#   {'entity': 'I-ORG',
#    'score': 0.9910846,
#    'index': 6,
#    'word': 'Star',
#    'start': 26,
#    'end': 30}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.788192,
#    'index': 4,
#    'word': 'Red',
#    'start': 13,
#    'end': 16},
#   {'entity': 'I-ORG',
#    'score': 0.8073133,
#    'index': 5,
#    'word': 'Leader',
#    'start': 17,
#    'end': 23}],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.99864393,
#    'index': 3,
#    'word': 'Red',
#    'start': 11,
#    'end': 14},
#   {'entity': 'I-ORG',
#    'score': 0.99808145,
#    'index': 4,
#    'word': 'Group',
#    'start': 15,
#    'end': 20},
#   {'entity': 'I-ORG',
#    'score': 0.99819297,
#    'index': 5,
#    'word': 'Ren',
#    'start': 21,
#    'end': 24},
#   {'entity': 'I-ORG',
#    'score': 0.68473995,
#    'index': 6,
#    'word': '##dez',
#    'start': 24,
#    'end': 27},
#   {'entity': 'I-ORG',
#    'score': 0.6235367,
#    'index': 7,
#    'word': '##vous',
#    'start': 27,
#    'end': 31}],
#  [{'entity': 'B-MISC',
#    'score': 0.88885874,
#    'index': 3,
#    'word': 'Red',
#    'start': 8,
#    'end': 11},
#   {'entity': 'I-MISC',
#    'score': 0.9676638,
#    'index': 4,
#    'word': 'Two',
#    'start': 12,
#    'end': 15}],
#  [],
#  [{'entity': 'I-MISC',
#    'score': 0.5233693,
#    'index': 4,
#    'word': 'Leader',
#    'start': 14,
#    'end': 20},
#   {'entity': 'I-MISC',
#    'score': 0.70820796,
#    'index': 5,
#    'word': 'Co',
#    'start': 21,
#    'end': 23}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9573979,
#    'index': 1,
#    'word': 'Target',
#    'start': 0,
#    'end': 6}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-ORG',
#    'score': 0.9305479,
#    'index': 7,
#    'word': 'Red',
#    'start': 16,
#    'end': 19},
#   {'entity': 'I-ORG',
#    'score': 0.95836794,
#    'index': 8,
#    'word': 'Leader',
#    'start': 20,
#    'end': 26}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.50826865,
#    'index': 3,
#    'word': 'Big',
#    'start': 11,
#    'end': 14},
#   {'entity': 'B-ORG',
#    'score': 0.4700864,
#    'index': 15,
#    'word': 'Be',
#    'start': 56,
#    'end': 58},
#   {'entity': 'I-ORG',
#    'score': 0.36915204,
#    'index': 17,
#    'word': '##ar',
#    'start': 60,
#    'end': 62},
#   {'entity': 'I-ORG',
#    'score': 0.59687334,
#    'index': 18,
#    'word': "'",
#    'start': 62,
#    'end': 63},
#   {'entity': 'I-ORG',
#    'score': 0.71906674,
#    'index': 19,
#    'word': 's',
#    'start': 63,
#    'end': 64},
#   {'entity': 'I-LOC',
#    'score': 0.5284548,
#    'index': 20,
#    'word': 'Canyon',
#    'start': 65,
#    'end': 71}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-PER',
#    'score': 0.5195333,
#    'index': 1,
#    'word': 'Art',
#    'start': 0,
#    'end': 3}],
#  [],
#  [],
#  [],
#  ...]

# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.7.6.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Using cached thinc-8.2.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Using cached srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.26.4)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Using cached blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.19.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl (41 kB)
# Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 23.9 MB/s eta 0:00:00
# Using cached murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl (26 kB)
# Using cached preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl (128 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl (488 kB)
# Using cached thinc-8.2.5-cp311-cp311-macosx_11_0_arm64.whl (773 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 6.4 MB/s eta 0:00:00
# Using cached blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl (1.1 MB)
# Downloading cloudpathlib-0.19.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 68.7 MB/s eta 0:00:0000:0100:01
# Downloading marisa_trie-1.2.0-cp311-cp311-macosx_11_0_arm64.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.6/174.6 kB 22.7 MB/s eta 0:00:00
# Building wheels for collected packages: spacy
#   Building wheel for spacy (pyproject.toml) ... done
#   Created wheel for spacy: filename=spacy-3.7.6-cp311-cp311-macosx_11_0_arm64.whl size=5912829 sha256=a96b8762952ac2ad3b0edfc5cae578a738f765f00d5f757f884ba200b4a4735e
#   Stored in directory: /Users/tarikrashada/Library/Caches/pip/wheels/d4/20/60/0719a53a3a30f17c67a2beb43d9b4a4cc30751716d1f4a2416
# Successfully built spacy
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, murmurhash, marisa-trie, cloudpathlib, catalogue, blis, srsly, preshed, language-data, langcodes, confection, weasel, thinc, spacy
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.19.0 confection-0.1.5 cymem-2.0.8 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.2.0 murmurhash-1.0.10 preshed-3.0.9 spacy-3.7.6 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.5 wasabi-1.1.3 weasel-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_trf
# Out:
# Collecting en-core-web-trf==3.7.3
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 14.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/anaconda3/lib/python3.11/site-packages (from en-core-web-trf==3.7.3) (3.7.6)
# Collecting spacy-curated-transformers<0.3.0,>=0.2.0 (from en-core-web-trf==3.7.3)
#   Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.1.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.26.4)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading curated_tokenizers-0.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.12.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.2.1)
# Requirement already satisfied: regex>=2022 in /opt/anaconda3/lib/python3.11/site-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2023.10.3)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.5)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.13.1)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.1)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2023.10.0)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.2.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.15.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.0)
# Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 kB 6.2 MB/s eta 0:00:0000:01
# Downloading curated_tokenizers-0.0.9-cp311-cp311-macosx_11_0_arm64.whl (703 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 703.3/703.3 kB 19.5 MB/s eta 0:00:00
# Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: curated-tokenizers, curated-transformers, spacy-curated-transformers, en-core-web-trf
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en-core-web-trf-3.7.3 spacy-curated-transformers-0.2.2
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
# !pip install https://huggingface.co/spacy/en_core_web_trf/resolve/main/en_core_web_trf-any-py3-none-any.whl

# Using spacy.load().
import spacy
nlp_model = spacy.load("en_core_web_trf")
# Out:
# Collecting en-core-web-trf==any
#   Downloading https://huggingface.co/spacy/en_core_web_trf/resolve/main/en_core_web_trf-any-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 10.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/anaconda3/lib/python3.11/site-packages (from en-core-web-trf==any) (3.7.6)
# Requirement already satisfied: spacy-curated-transformers<0.3.0,>=0.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from en-core-web-trf==any) (0.2.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (3.1.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (1.26.4)
# Requirement already satisfied: curated-transformers<0.2.0,>=0.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (0.1.1)
# Requirement already satisfied: curated-tokenizers<0.1.0,>=0.0.9 in /opt/anaconda3/lib/python3.11/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (0.0.9)
# Requirement already satisfied: torch>=1.12.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (2.2.1)
# Requirement already satisfied: regex>=2022 in /opt/anaconda3/lib/python3.11/site-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (2023.10.3)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (0.1.5)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (3.13.1)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (3.1)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (2023.10.0)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (1.2.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (2.15.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==any) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==any) (0.1.0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 5
#       3 # Using spacy.load().
#       4 import spacy
# ----> 5 nlp_model = spacy.load("en_core_web_trf")
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/util.py:465, in load_model(name, vocab, disable, enable, exclude, config)
#     463     return get_lang_class(name.replace("blank:", ""))()
#     464 if is_package(name):  # installed as package
# --> 465     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     466 if Path(name).exists():  # path to model data directory
#     467     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/util.py:501, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     484 """Load a model from an installed package.
#     485
#     486 name (str): The package name.
#    (...)
#     498 RETURNS (Language): The loaded nlp object.
#     499 """
#     500 cls = importlib.import_module(name)
# --> 501 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File /opt/anaconda3/lib/python3.11/site-packages/en_core_web_trf/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/util.py:682, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     680 if not model_path.exists():
#     681     raise IOError(Errors.E052.format(path=data_path))
# --> 682 return load_model_from_path(
#     683     data_path,
#     684     vocab=vocab,
#     685     meta=meta,
#     686     disable=disable,
#     687     enable=enable,
#     688     exclude=exclude,
#     689     config=config,
#     690 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/util.py:539, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     537 overrides = dict_to_dot(config, for_overrides=True)
#     538 config = load_config(config_path, overrides=overrides)
# --> 539 nlp = load_model_from_config(
#     540     config,
#     541     vocab=vocab,
#     542     disable=disable,
#     543     enable=enable,
#     544     exclude=exclude,
#     545     meta=meta,
#     546 )
#     547 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/util.py:587, in load_model_from_config(config, meta, vocab, disable, enable, exclude, auto_fill, validate)
#     584 # This will automatically handle all codes registered via the languages
#     585 # registry, including custom subclasses provided via entry points
#     586 lang_cls = get_lang_class(nlp_config["lang"])
# --> 587 nlp = lang_cls.from_config(
#     588     config,
#     589     vocab=vocab,
#     590     disable=disable,
#     591     enable=enable,
#     592     exclude=exclude,
#     593     auto_fill=auto_fill,
#     594     validate=validate,
#     595     meta=meta,
#     596 )
#     597 return nlp
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/language.py:1889, in Language.from_config(cls, config, vocab, disable, enable, exclude, meta, auto_fill, validate)
#    1886     factory = pipe_cfg.pop("factory")
#    1887     # The pipe name (key in the config) here is the unique name
#    1888     # of the component, not necessarily the factory
# -> 1889     nlp.add_pipe(
#    1890         factory,
#    1891         name=pipe_name,
#    1892         config=pipe_cfg,
#    1893         validate=validate,
#    1894         raw_config=raw_config,
#    1895     )
#    1896 else:
#    1897     assert "source" in pipe_cfg
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/language.py:821, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     817     pipe_component, factory_name = self.create_pipe_from_source(
#     818         factory_name, source, name=name
#     819     )
#     820 else:
# --> 821     pipe_component = self.create_pipe(
#     822         factory_name,
#     823         name=name,
#     824         config=config,
#     825         raw_config=raw_config,
#     826         validate=validate,
#     827     )
#     828 pipe_index = self._get_pipe_index(before, after, first, last)
#     829 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File /opt/anaconda3/lib/python3.11/site-packages/spacy/language.py:690, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     682 if not self.has_factory(factory_name):
#     683     err = Errors.E002.format(
#     684         name=factory_name,
#     685         opts=", ".join(self.factory_names),
#    (...)
#     688         lang_code=self.lang,
#     689     )
# --> 690     raise ValueError(err)
#     691 pipe_meta = self.get_factory_meta(factory_name)
#     692 # This is unideal, but the alternative would mean you always need to
#     693 # specify the full config settings, which is not really viable.
#
# ValueError: [E002] Can't find factory for 'curated_transformer' for language English (en). This usually happens when spaCy calls `nlp.create_pipe` with a custom component name that's not registered on the current language class. If you're using a custom component, make sure you've added the decorator `@Language.component` (for function components) or `@Language.factory` (for class components).
#
# Available factories: attribute_ruler, tok2vec, merge_noun_chunks, merge_entities, merge_subtokens, token_splitter, doc_cleaner, parser, beam_parser, lemmatizer, trainable_lemmatizer, entity_linker, entity_ruler, tagger, morphologizer, ner, beam_ner, senter, sentencizer, spancat, spancat_singlelabel, span_finder, future_entity_ruler, span_ruler, textcat, textcat_multilabel, en.lemmatizer
